# %% [markdown]
# # Federated Learning with Flower

# %% [markdown]
# #### This notebook presents a simple Federated Learning example / application on developing a Machine Learning model as an Intrusion Detection System for defending against Cyberattacks using distributed and private data.
# #### This example uses Docker containers as independent workers / clients for performing the client model training on the limited and private local client data.
# #### This example was developed as part of the research conducted at [MetaMind Innovations - MINDS](https://metamind.gr/) in the framework of the [ELECTRON H2020](https://metamind.gr/project/electron-h2020/) project.

# %% [markdown]
# ### This notebook, as well as the Flower example, were implemented and tested using Python v3.11, Flower v1.5 and TensorFlow v2.14.1

# %% [markdown]
# ## Set Up Flower Environment

# %%
# !pip install --quiet --upgrade flwr==1.5.0
# !pip install --quiet --upgrade tensorflow-cpu==2.14.1
# !pip install --quiet --upgrade scikit-learn
# !pip install --quiet --upgrade pandas
# !pip install --quiet --upgrade matplotlib
# !pip install --quiet --upgrade git+https://github.com/nepiskopos/py7zr.git

# %% [markdown]
# ## Dataset

# %% [markdown]
# This dataset is part of the [DNP3 Intrusion Detection Dataset](https://ieee-dataport.org/documents/dnp3-intrusion-detection-dataset) -- DOI: [10.21227/s7h0-b081](https://dx.doi.org/10.21227/s7h0-b081) -- published by [ITHACA – University of Western Macedonia](http://ithaca.ece.uowm.gr/).

# %%
import errno
import os
import py7zr
import re
import shutil
import sys
import time
import urllib


def reporthook(count, block_size, total_size):
    global start_time
    if count == 0:
        start_time = time.time()
        return
    duration = time.time() - start_time
    progress_size = int(count * block_size)
    speed = int(progress_size / (1024 * duration))
    percent = int(count * block_size * 100 / total_size)
    sys.stdout.write("\r...%d%%, %d MB, %d KB/s, %d seconds passed" %
                    (percent, progress_size / (1024 * 1024), speed, duration))
    sys.stdout.flush()

def download(url, filename):
    urllib.request.urlretrieve(url, filename, reporthook)

def extract(archive, target_dir):
    archive = py7zr.SevenZipFile(archive, mode='r')
    try:
        os.makedirs(target_dir)
        
        archive.extractall(path=target_dir)
        archive.close()
        
        print(f"Archive '{archive}' extracted successfully!")
    except OSError as e:
        if e.errno == errno.EEXIST:
            archive.extractall(path=target_dir)
            archive.close()
            
            print(f"Archive '{archive}' extracted successfully!")
        else:
            print(f"Archive '{archive}' failed to extract...")


base_data_dir = './datasets'

if not os.path.isdir(os.path.join(base_data_dir, 'Training_Testing_Balanced_CSV_Files')):
    filename = 'DNP3_Intrusion_Detection_Dataset_Final.7z'
    
    if not py7zr.is_7zfile(filename):
        url = ('https://zenodo.org/records/7348493/files/DNP3_Intrusion_Detection_Dataset_Final.7z?download=1')
        download(url, filename)
    
    extract(filename, base_data_dir)

    innerDirs = os.listdir(base_data_dir)
    for dir in innerDirs:
        if (re.search('2020*', dir)):
            shutil.rmtree(os.path.join(base_data_dir, dir))
    
    os.remove(os.path.join('.', filename))
# Out:
# ...100%, 185 MB, 3047 KB/s, 62 seconds passedArchive '<py7zr.py7zr.SevenZipFile object at 0x117016b70>' extracted successfully!

# %%
import collections
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

pd.set_option('future.no_silent_downcasting', True)

# %matplotlib inline

# %% [markdown]
# We must choose which dataset version to facilitate for the experimentation.
#
# We must also choose $3 \leq N \leq 5$ distinct federated learning workers.
#
# For this example we use the CICFlowMeter dataset with 3 workers.

# %%
tp = 'cic'      # Type: dataset type (CICFlowMeter or Custom Python parser), choose between 'cic' and 'custom'
n_workers = 3   # N: number of federated workers, choose between 3 and 5

# %% [markdown]
# Perform some value checks

# %%
assert tp in ('cic', 'custom'), "Wrong dataset type, choose between 'cic' and 'custom'"
assert n_workers in (3, 4, 5), "Wrong number of workers, choose between 3 and 5"

# %%
path = os.path.join(base_data_dir, 'Training_Testing_Balanced_CSV_Files')

if tp == 'cic':
    dataset = f'CICFlowMeter'
else:
    dataset = 'Custom_DNP3_Parser'

if 'CIC' in dataset:
    n = dataset.split('_')[-1]
    train_csv = os.path.join(os.path.join(path, dataset), f'CICFlowMeter_Training_Balanced.csv')
    test_csv = os.path.join(os.path.join(path, dataset), f'CICFlowMeter_Testing_Balanced.csv')
elif 'Custom' in dataset:
    n = dataset.split('_')
    train_csv = os.path.join(os.path.join(path, dataset), f'Custom_DNP3_Parser_Training_Balanced.csv')
    test_csv = os.path.join(os.path.join(path, dataset), f'Custom_DNP3_Parser_Testing_Balanced.csv')
else:
    raise Exception("Wrong dataset")

df_train = pd.read_csv(train_csv, sep=r'\s*,\s*', header=0, 
                       encoding='ascii', engine='python')
df_test = pd.read_csv(train_csv, sep=r'\s*,\s*', header=0, 
                      encoding='ascii', engine='python')

# %% [markdown]
# Let's perform some data exploration.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 86 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       5126 non-null   int64
#  1   Unnamed: 0         5126 non-null   int64
#  2   Flow ID            5126 non-null   object
#  3   Src IP             5126 non-null   object
#  4   Src Port           5126 non-null   int64
#  5   Dst IP             5126 non-null   object
#  6   Dst Port           5126 non-null   int64
#  7   Protocol           5126 non-null   int64
#  8   Timestamp          5126 non-null   object
#  9   Flow Duration      5126 non-null   int64
#  10  Tot Fwd Pkts       5126 non-null   int64
#  11  Tot Bwd Pkts       5126 non-null   int64
#  12  TotLen Fwd Pkts    5126 non-null   float64
#  13  TotLen Bwd Pkts    5126 non-null   float64
#  14  Fwd Pkt Len Max    5126 non-null   float64
#  15  Fwd Pkt Len Min    5126 non-null   float64
#  16  Fwd Pkt Len Mean   5126 non-null   float64
#  17  Fwd Pkt Len Std    5126 non-null   float64
#  18  Bwd Pkt Len Max    5126 non-null   float64
#  19  Bwd Pkt Len Min    5126 non-null   float64
#  20  Bwd Pkt Len Mean   5126 non-null   float64
#  21  Bwd Pkt Len Std    5126 non-null   float64
#  22  Flow Byts/s        5126 non-null   float64
#  23  Flow Pkts/s        5126 non-null   float64
#  24  Flow IAT Mean      5126 non-null   float64
#  25  Flow IAT Std       5126 non-null   float64
#  26  Flow IAT Max       5126 non-null   float64
#  27  Flow IAT Min       5126 non-null   float64
#  28  Fwd IAT Tot        5126 non-null   float64
#  29  Fwd IAT Mean       5126 non-null   float64
#  30  Fwd IAT Std        5126 non-null   float64
#  31  Fwd IAT Max        5126 non-null   float64
#  32  Fwd IAT Min        5126 non-null   float64
#  33  Bwd IAT Tot        5126 non-null   float64
#  34  Bwd IAT Mean       5126 non-null   float64
#  35  Bwd IAT Std        5126 non-null   float64
#  36  Bwd IAT Max        5126 non-null   float64
#  37  Bwd IAT Min        5126 non-null   float64
#  38  Fwd PSH Flags      5126 non-null   int64
#  39  Bwd PSH Flags      5126 non-null   int64
#  40  Fwd URG Flags      5126 non-null   int64
#  41  Bwd URG Flags      5126 non-null   int64
#  42  Fwd Header Len     5126 non-null   int64
#  43  Bwd Header Len     5126 non-null   int64
#  44  Fwd Pkts/s         5126 non-null   float64
#  45  Bwd Pkts/s         5126 non-null   float64
#  46  Pkt Len Min        5126 non-null   float64
#  47  Pkt Len Max        5126 non-null   float64
#  48  Pkt Len Mean       5126 non-null   float64
#  49  Pkt Len Std        5126 non-null   float64
#  50  Pkt Len Var        5126 non-null   float64
#  51  FIN Flag Cnt       5126 non-null   int64
#  52  SYN Flag Cnt       5126 non-null   int64
#  53  RST Flag Cnt       5126 non-null   int64
#  54  PSH Flag Cnt       5126 non-null   int64
#  55  ACK Flag Cnt       5126 non-null   int64
#  56  URG Flag Cnt       5126 non-null   int64
#  57  CWE Flag Count     5126 non-null   int64
#  58  ECE Flag Cnt       5126 non-null   int64
#  59  Down/Up Ratio      5126 non-null   float64
#  60  Pkt Size Avg       5126 non-null   float64
#  61  Fwd Seg Size Avg   5126 non-null   float64
#  62  Bwd Seg Size Avg   5126 non-null   float64
#  63  Fwd Byts/b Avg     5126 non-null   int64
#  64  Fwd Pkts/b Avg     5126 non-null   int64
#  65  Fwd Blk Rate Avg   5126 non-null   int64
#  66  Bwd Byts/b Avg     5126 non-null   int64
#  67  Bwd Pkts/b Avg     5126 non-null   int64
#  68  Bwd Blk Rate Avg   5126 non-null   int64
#  69  Subflow Fwd Pkts   5126 non-null   int64
#  70  Subflow Fwd Byts   5126 non-null   int64
#  71  Subflow Bwd Pkts   5126 non-null   int64
#  72  Subflow Bwd Byts   5126 non-null   int64
#  73  Init Fwd Win Byts  5126 non-null   int64
#  74  Init Bwd Win Byts  5126 non-null   int64
#  75  Fwd Act Data Pkts  5126 non-null   int64
#  76  Fwd Seg Size Min   5126 non-null   int64
#  77  Active Mean        5126 non-null   float64
#  78  Active Std         5126 non-null   float64
#  79  Active Max         5126 non-null   float64
#  80  Active Min         5126 non-null   float64
#  81  Idle Mean          5126 non-null   float64
#  82  Idle Std           5126 non-null   float64
#  83  Idle Max           5126 non-null   float64
#  84  Idle Min           5126 non-null   float64
#  85  Label              5126 non-null   object
# dtypes: float64(45), int64(36), object(5)
# memory usage: 3.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 86 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       5126 non-null   int64
#  1   Unnamed: 0         5126 non-null   int64
#  2   Flow ID            5126 non-null   object
#  3   Src IP             5126 non-null   object
#  4   Src Port           5126 non-null   int64
#  5   Dst IP             5126 non-null   object
#  6   Dst Port           5126 non-null   int64
#  7   Protocol           5126 non-null   int64
#  8   Timestamp          5126 non-null   object
#  9   Flow Duration      5126 non-null   int64
#  10  Tot Fwd Pkts       5126 non-null   int64
#  11  Tot Bwd Pkts       5126 non-null   int64
#  12  TotLen Fwd Pkts    5126 non-null   float64
#  13  TotLen Bwd Pkts    5126 non-null   float64
#  14  Fwd Pkt Len Max    5126 non-null   float64
#  15  Fwd Pkt Len Min    5126 non-null   float64
#  16  Fwd Pkt Len Mean   5126 non-null   float64
#  17  Fwd Pkt Len Std    5126 non-null   float64
#  18  Bwd Pkt Len Max    5126 non-null   float64
#  19  Bwd Pkt Len Min    5126 non-null   float64
#  20  Bwd Pkt Len Mean   5126 non-null   float64
#  21  Bwd Pkt Len Std    5126 non-null   float64
#  22  Flow Byts/s        5126 non-null   float64
#  23  Flow Pkts/s        5126 non-null   float64
#  24  Flow IAT Mean      5126 non-null   float64
#  25  Flow IAT Std       5126 non-null   float64
#  26  Flow IAT Max       5126 non-null   float64
#  27  Flow IAT Min       5126 non-null   float64
#  28  Fwd IAT Tot        5126 non-null   float64
#  29  Fwd IAT Mean       5126 non-null   float64
#  30  Fwd IAT Std        5126 non-null   float64
#  31  Fwd IAT Max        5126 non-null   float64
#  32  Fwd IAT Min        5126 non-null   float64
#  33  Bwd IAT Tot        5126 non-null   float64
#  34  Bwd IAT Mean       5126 non-null   float64
#  35  Bwd IAT Std        5126 non-null   float64
#  36  Bwd IAT Max        5126 non-null   float64
#  37  Bwd IAT Min        5126 non-null   float64
#  38  Fwd PSH Flags      5126 non-null   int64
#  39  Bwd PSH Flags      5126 non-null   int64
#  40  Fwd URG Flags      5126 non-null   int64
#  41  Bwd URG Flags      5126 non-null   int64
#  42  Fwd Header Len     5126 non-null   int64
#  43  Bwd Header Len     5126 non-null   int64
#  44  Fwd Pkts/s         5126 non-null   float64
#  45  Bwd Pkts/s         5126 non-null   float64
#  46  Pkt Len Min        5126 non-null   float64
#  47  Pkt Len Max        5126 non-null   float64
#  48  Pkt Len Mean       5126 non-null   float64
#  49  Pkt Len Std        5126 non-null   float64
#  50  Pkt Len Var        5126 non-null   float64
#  51  FIN Flag Cnt       5126 non-null   int64
#  52  SYN Flag Cnt       5126 non-null   int64
#  53  RST Flag Cnt       5126 non-null   int64
#  54  PSH Flag Cnt       5126 non-null   int64
#  55  ACK Flag Cnt       5126 non-null   int64
#  56  URG Flag Cnt       5126 non-null   int64
#  57  CWE Flag Count     5126 non-null   int64
#  58  ECE Flag Cnt       5126 non-null   int64
#  59  Down/Up Ratio      5126 non-null   float64
#  60  Pkt Size Avg       5126 non-null   float64
#  61  Fwd Seg Size Avg   5126 non-null   float64
#  62  Bwd Seg Size Avg   5126 non-null   float64
#  63  Fwd Byts/b Avg     5126 non-null   int64
#  64  Fwd Pkts/b Avg     5126 non-null   int64
#  65  Fwd Blk Rate Avg   5126 non-null   int64
#  66  Bwd Byts/b Avg     5126 non-null   int64
#  67  Bwd Pkts/b Avg     5126 non-null   int64
#  68  Bwd Blk Rate Avg   5126 non-null   int64
#  69  Subflow Fwd Pkts   5126 non-null   int64
#  70  Subflow Fwd Byts   5126 non-null   int64
#  71  Subflow Bwd Pkts   5126 non-null   int64
#  72  Subflow Bwd Byts   5126 non-null   int64
#  73  Init Fwd Win Byts  5126 non-null   int64
#  74  Init Bwd Win Byts  5126 non-null   int64
#  75  Fwd Act Data Pkts  5126 non-null   int64
#  76  Fwd Seg Size Min   5126 non-null   int64
#  77  Active Mean        5126 non-null   float64
#  78  Active Std         5126 non-null   float64
#  79  Active Max         5126 non-null   float64
#  80  Active Min         5126 non-null   float64
#  81  Idle Mean          5126 non-null   float64
#  82  Idle Std           5126 non-null   float64
#  83  Idle Max           5126 non-null   float64
#  84  Idle Min           5126 non-null   float64
#  85  Label              5126 non-null   object
# dtypes: float64(45), int64(36), object(5)
# memory usage: 3.4+ MB

# %% [markdown]
# As a preprocessing step, we transorm the "Label" feature from string to categorical and then to numeric.

# %%
df_train['Label'] = df_train['Label'].str.lower()
df_test['Label'] = df_test['Label'].str.lower()

unique_labels = list(df_train.Label.astype('category').unique())
unique_codes = list(df_train.Label.astype('category').cat.codes.unique())

mapping = dict(zip(unique_labels, unique_codes))
mapping_inv = dict(zip(unique_codes, unique_labels))

# %%
mapping
# Out:
# {'init_data': 5,
#  'disable_unsolicited': 2,
#  'warm_restart': 10,
#  'mitm_dos': 6,
#  'arp_poisoning': 0,
#  'normal': 7,
#  'dnp3_enumerate': 3,
#  'cold_restart': 1,
#  'dnp3_info': 4,
#  'replay': 8,
#  'stop_app': 9}

# %%
df_train['Label'] = df_train['Label'].astype('category').cat.rename_categories(mapping)
df_test['Label'] = df_test['Label'].astype('category').cat.rename_categories(mapping)

# %% [markdown]
# Now, we remove the features which do not assist with training a ML model.

# %%
train = df_train.iloc[:,9:]
test = df_test.iloc[:,9:]

# %% [markdown]
# We rename the "Label" column to "y".

# %%
train.rename(columns={"Label": "y"}, inplace=True, errors="raise")
test.rename(columns={"Label": "y"}, inplace=True, errors="raise")

# %% [markdown]
# We drop Inf and NaN values both in the training and in test feature data.

# %%
# Replace Inf values with NaN
train.replace([np.inf, -np.inf], np.nan, inplace=True)
test.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN values
train.dropna(inplace=True)
test.dropna(inplace=True)

# %% [markdown]
# We store the modified datasets into new local CSV files for future use and model evaluation.

# %%
directory = os.path.join(base_data_dir, 'federated_datasets')

try:
    os.makedirs(directory)
    train.to_csv(os.path.join(directory, 'train_data.csv'), index=False)
    test.to_csv(os.path.join(directory, 'test_data.csv'), index=False)
except OSError as e:
    if e.errno != errno.EEXIST:
        raise
    else:   
        train.to_csv(os.path.join(directory, 'train_data.csv'), index=False)
        test.to_csv(os.path.join(directory, 'test_data.csv'), index=False)

# %% [markdown]
# Each worker will be assigned a subset of the dataset with $\lfloor {M \over N} \rfloor$ data points.
#
# Each worker data is stored as a seperate CSV file with the proper naming scheme.

# %%
n_samples = int(train.shape[0] / n_workers)

assert type(n_workers) == int, "Non-int number of workers"
assert n_workers >= 3 and n_workers <= df_train.shape[0], "At least 3 workers and at most as many workers as the number of samples are allowed"
assert n_samples > 0, "Each worker must be assigned at least one data point"

# %%
client_data = []
train_copy = train.copy()

for i in range(n_workers):
    sample = train_copy.sample(n=n_samples)
    sample.to_csv(os.path.join(directory, f'client_train_data_{i+1}.csv'), index=False)
    train_copy.drop(index=sample.index, inplace=True)
    client_data.append(sample)

# %% [markdown]
# Let's check the number of points in each straggler's training data.

# %%
for i in range(n_workers):
    print(f"Worker {i+1} training data contains {len(client_data[i])} points")
# Out:
# Worker 1 training data contains 1708 points
# Worker 2 training data contains 1708 points
# Worker 3 training data contains 1708 points

# %% [markdown]
# Let's perform some statistical analysis on the difference in the number of samples for each digit in each client dataset.

# %%
# Number of examples per layer for a sample of clients
fig = plt.figure(figsize=(20, 7))
fig.suptitle('Label Counts for a Sample of Worker Data')
fig.tight_layout()

for i in range(n_workers):
    m = 0
    plot_data = collections.defaultdict(list)
    sample = client_data[i]
    for label in sample['y']:
        # Append counts individually per label to make plots
        # more colorful instead of one color per plot.
        plot_data[label].append(label)
        m = max(m, len(plot_data[label]))
    
    n_cols = n_workers if n_workers < 5 else 5
    xlim = [0, m+(20-m%20)]
    ylim = [min(unique_codes)-1, max(unique_codes)+1]
    yticks = list(range(min(unique_codes), max(unique_codes)+1))
    yticks_labels = [mapping_inv[k] for k in range(0, max(unique_codes)+1)]
    
    plt.subplot(int(n_workers / 5)+1, n_cols, i+1)
    plt.subplots_adjust(wspace=0.3)
    plt.title('Worker {}'.format(i+1))
    plt.xlabel('#points')
    plt.xlim(xlim)
    plt.ylabel('Label')
    plt.ylim(ylim)
    plt.yticks(yticks, labels=yticks_labels)
    
    # plot values on top of bars
    for key in plot_data:
        if len(plot_data[key]) > 0:
            plt.text(len(plot_data[key])+8, int(key)-0.1, str(len(plot_data[key])), ha='center')
    
    for j in range(min(unique_codes),max(unique_codes)+1):
        plt.hist(
            plot_data[j],
            density=False,
            bins=[k-0.5 for k in range(min(unique_codes),max(unique_codes)+2)],
            orientation='horizontal'
        )

# %% [markdown]
# ## Centralized model

# %% [markdown]
# Let's train a centralized IDS model to use as a reference.

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# We have to scale the data to avoid huge value deviations.

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(train.drop(['y'], axis=1).to_numpy())
y_train = train['y'].to_numpy()
X_test = scaler.transform(test.drop(['y'], axis=1).to_numpy())
y_test = test['y'].to_numpy()

# %% [markdown]
# Then, we are better off using one-hot-vectors than scalars for the label representation.

# %%
y_cat_train = to_categorical(y_train)
y_cat_test = to_categorical(y_test)

# %% [markdown]
# We define a MLP model with one hidden layer.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(units=50, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=y_cat_test.shape[1], activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# We use early stopping monitoring the validation loss to avoid overfitting.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# %% [markdown]
# Let's train the model.

# %%
model.fit(
    x=X_train, 
    y=y_cat_train, 
    epochs=300,
    validation_data=(X_test, y_cat_test),
    verbose=1,
    batch_size=64,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2402 - loss: 2.1560 - val_accuracy: 0.6133 - val_loss: 1.1803
# Epoch 2/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.4993 - loss: 1.2046 - val_accuracy: 0.5795 - val_loss: 1.0612
# Epoch 3/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.5200 - loss: 1.0986 - val_accuracy: 0.6121 - val_loss: 1.0105
# Epoch 4/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.5457 - loss: 1.0586 - val_accuracy: 0.6070 - val_loss: 0.9713
# Epoch 5/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.5666 - loss: 1.0107 - val_accuracy: 0.6925 - val_loss: 0.9264
# Epoch 6/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.6043 - loss: 0.9446 - val_accuracy: 0.6076 - val_loss: 0.8856
# Epoch 7/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.5996 - loss: 0.9131 - val_accuracy: 0.6898 - val_loss: 0.8355
# Epoch 8/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.6310 - loss: 0.8592 - val_accuracy: 0.6872 - val_loss: 0.8046
# Epoch 9/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.6419 - loss: 0.8326 - val_accuracy: 0.6892 - val_loss: 0.7688
# Epoch 10/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.6643 - loss: 0.7886 - val_accuracy: 0.6974 - val_loss: 0.7406
# Epoch 11/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.6575 - loss: 0.7686 - val_accuracy: 0.6880 - val_loss: 0.7200
# Epoch 12/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.6693 - loss: 0.7507 - val_accuracy: 0.6954 - val_loss: 0.7003
# Epoch 13/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - accuracy: 0.6668 - loss: 0.7316 - val_accuracy: 0.6915 - val_loss: 0.6816
# Epoch 14/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.6666 - loss: 0.7032 - val_accuracy: 0.6903 - val_loss: 0.6671
# Epoch 15/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.6855 - loss: 0.6941 - val_accuracy: 0.6983 - val_loss: 0.6572
# Epoch 16/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.6668 - loss: 0.6716 - val_accuracy: 0.6935 - val_loss: 0.6423
# Epoch 17/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.6756 - loss: 0.6676 - val_accuracy: 0.6929 - val_loss: 0.6280
# Epoch 18/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.6738 - loss: 0.6531 - val_accuracy: 0.6983 - val_loss: 0.6177
# Epoch 19/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.6868 - loss: 0.6344 - val_accuracy: 0.6956 - val_loss: 0.6111
# Epoch 20/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.6960 - loss: 0.6291 - val_accuracy: 0.6948 - val_loss: 0.5995
# Epoch 21/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.6923 - loss: 0.6070 - val_accuracy: 0.6946 - val_loss: 0.5911
# Epoch 22/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.6869 - loss: 0.6228 - val_accuracy: 0.6980 - val_loss: 0.5830
# Epoch 23/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.6972 - loss: 0.5944 - val_accuracy: 0.7024 - val_loss: 0.5776
# Epoch 24/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.6902 - loss: 0.5973 - val_accuracy: 0.7067 - val_loss: 0.5740
# Epoch 25/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.6913 - loss: 0.5951 - val_accuracy: 0.7020 - val_loss: 0.5663
# Epoch 26/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7037 - loss: 0.5775 - val_accuracy: 0.6960 - val_loss: 0.5614
# Epoch 27/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.6858 - loss: 0.5874 - val_accuracy: 0.7130 - val_loss: 0.5559
# Epoch 28/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6920 - loss: 0.5767 - val_accuracy: 0.6948 - val_loss: 0.5533
# Epoch 29/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.7091 - loss: 0.5609 - val_accuracy: 0.6962 - val_loss: 0.5497
# Epoch 30/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7022 - loss: 0.5651 - val_accuracy: 0.6980 - val_loss: 0.5447
# Epoch 31/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.6870 - loss: 0.5681 - val_accuracy: 0.6970 - val_loss: 0.5418
# Epoch 32/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.6887 - loss: 0.5651 - val_accuracy: 0.7073 - val_loss: 0.5433
# Epoch 33/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.6986 - loss: 0.5510 - val_accuracy: 0.7052 - val_loss: 0.5368
# Epoch 34/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.6853 - loss: 0.5753 - val_accuracy: 0.6997 - val_loss: 0.5339
# Epoch 35/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.7062 - loss: 0.5495 - val_accuracy: 0.7175 - val_loss: 0.5312
# Epoch 36/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.6842 - loss: 0.5524 - val_accuracy: 0.7060 - val_loss: 0.5323
# Epoch 37/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.6772 - loss: 0.5607 - val_accuracy: 0.7005 - val_loss: 0.5302
# Epoch 38/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.6930 - loss: 0.5537 - val_accuracy: 0.7036 - val_loss: 0.5270
# Epoch 39/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.6928 - loss: 0.5469 - val_accuracy: 0.7210 - val_loss: 0.5242
# Epoch 40/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7015 - loss: 0.5370 - val_accuracy: 0.6972 - val_loss: 0.5223
# Epoch 41/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.6860 - loss: 0.5447 - val_accuracy: 0.6980 - val_loss: 0.5225
# Epoch 42/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.6838 - loss: 0.5482 - val_accuracy: 0.7095 - val_loss: 0.5267
# Epoch 43/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.6954 - loss: 0.5446 - val_accuracy: 0.7026 - val_loss: 0.5196
# Epoch 44/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.7147 - loss: 0.5386 - val_accuracy: 0.7100 - val_loss: 0.5170
# Epoch 45/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.6898 - loss: 0.5407 - val_accuracy: 0.7140 - val_loss: 0.5143
# Epoch 46/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.7001 - loss: 0.5344 - val_accuracy: 0.7114 - val_loss: 0.5179
# Epoch 47/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.6898 - loss: 0.5441 - val_accuracy: 0.7022 - val_loss: 0.5134
# Epoch 48/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.6926 - loss: 0.5327 - val_accuracy: 0.7028 - val_loss: 0.5117
# Epoch 49/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7093 - loss: 0.5262 - val_accuracy: 0.7136 - val_loss: 0.5103
# Epoch 50/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.6905 - loss: 0.5355 - val_accuracy: 0.7106 - val_loss: 0.5108
# Epoch 51/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7083 - loss: 0.5209 - val_accuracy: 0.7097 - val_loss: 0.5123
# Epoch 52/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.6887 - loss: 0.5351 - val_accuracy: 0.7044 - val_loss: 0.5096
# Epoch 53/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.7091 - loss: 0.5087 - val_accuracy: 0.7188 - val_loss: 0.5070
# Epoch 54/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.6984 - loss: 0.5397 - val_accuracy: 0.7099 - val_loss: 0.5084
# Epoch 55/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.6891 - loss: 0.5383 - val_accuracy: 0.7114 - val_loss: 0.5086
# Epoch 56/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7040 - loss: 0.5149 - val_accuracy: 0.7040 - val_loss: 0.5075
# Epoch 57/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.6907 - loss: 0.5260 - val_accuracy: 0.7032 - val_loss: 0.5046
# Epoch 58/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7035 - loss: 0.5292 - val_accuracy: 0.7200 - val_loss: 0.5043
# Epoch 59/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6918 - loss: 0.5233 - val_accuracy: 0.7089 - val_loss: 0.5054
# Epoch 60/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.6929 - loss: 0.5310 - val_accuracy: 0.7011 - val_loss: 0.5022
# Epoch 61/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7007 - loss: 0.5215 - val_accuracy: 0.7097 - val_loss: 0.5045
# Epoch 62/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.6986 - loss: 0.5260 - val_accuracy: 0.7223 - val_loss: 0.5019
# Epoch 63/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.7083 - loss: 0.5201 - val_accuracy: 0.7089 - val_loss: 0.5030
# Epoch 64/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.6992 - loss: 0.5210 - val_accuracy: 0.7104 - val_loss: 0.5020
# Epoch 65/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7025 - loss: 0.5286 - val_accuracy: 0.7151 - val_loss: 0.5003
# Epoch 66/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7137 - loss: 0.5158 - val_accuracy: 0.7296 - val_loss: 0.4990
# Epoch 67/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7162 - loss: 0.5077 - val_accuracy: 0.7052 - val_loss: 0.4999
# Epoch 68/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.6949 - loss: 0.5243 - val_accuracy: 0.7100 - val_loss: 0.5000
# Epoch 69/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7088 - loss: 0.5212 - val_accuracy: 0.7327 - val_loss: 0.4982
# Epoch 70/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.7192 - loss: 0.5076 - val_accuracy: 0.7231 - val_loss: 0.4969
# Epoch 71/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.6919 - loss: 0.5220 - val_accuracy: 0.7083 - val_loss: 0.4964
# Epoch 72/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.7054 - loss: 0.5090 - val_accuracy: 0.7220 - val_loss: 0.4961
# Epoch 73/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7004 - loss: 0.5042 - val_accuracy: 0.7116 - val_loss: 0.4976
# Epoch 74/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7119 - loss: 0.5129 - val_accuracy: 0.7141 - val_loss: 0.4971
# Epoch 75/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.7033 - loss: 0.5057 - val_accuracy: 0.7155 - val_loss: 0.4965
# Epoch 76/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.7135 - loss: 0.5064 - val_accuracy: 0.7149 - val_loss: 0.4942
# Epoch 77/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.7080 - loss: 0.5146 - val_accuracy: 0.7313 - val_loss: 0.4927
# Epoch 78/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7052 - loss: 0.5058 - val_accuracy: 0.7141 - val_loss: 0.4932
# Epoch 79/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7158 - loss: 0.5051 - val_accuracy: 0.7015 - val_loss: 0.4947
# Epoch 80/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.7096 - loss: 0.5098 - val_accuracy: 0.7102 - val_loss: 0.4916
# Epoch 81/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.6989 - loss: 0.5116 - val_accuracy: 0.7095 - val_loss: 0.4945
# Epoch 82/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7122 - loss: 0.5004 - val_accuracy: 0.7190 - val_loss: 0.4928
# Epoch 83/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7026 - loss: 0.5150 - val_accuracy: 0.7301 - val_loss: 0.4950
# Epoch 84/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.6983 - loss: 0.5217 - val_accuracy: 0.7149 - val_loss: 0.4924
# Epoch 85/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7070 - loss: 0.4987 - val_accuracy: 0.7225 - val_loss: 0.4910
# Epoch 86/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7019 - loss: 0.5115 - val_accuracy: 0.7208 - val_loss: 0.4915
# Epoch 87/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7153 - loss: 0.4961 - val_accuracy: 0.7063 - val_loss: 0.4903
# Epoch 88/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7103 - loss: 0.4983 - val_accuracy: 0.7303 - val_loss: 0.4893
# Epoch 89/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.7064 - loss: 0.5088 - val_accuracy: 0.7079 - val_loss: 0.4929
# Epoch 90/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7056 - loss: 0.5045 - val_accuracy: 0.7216 - val_loss: 0.4921
# Epoch 91/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.6881 - loss: 0.5216 - val_accuracy: 0.7118 - val_loss: 0.4921
# Epoch 92/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7062 - loss: 0.5033 - val_accuracy: 0.7180 - val_loss: 0.4879
# Epoch 93/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.7095 - loss: 0.5064 - val_accuracy: 0.7303 - val_loss: 0.4868
# Epoch 94/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.7066 - loss: 0.5038 - val_accuracy: 0.7155 - val_loss: 0.4862
# Epoch 95/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.7151 - loss: 0.4940 - val_accuracy: 0.7360 - val_loss: 0.4878
# Epoch 96/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.7073 - loss: 0.5041 - val_accuracy: 0.7163 - val_loss: 0.4866
# Epoch 97/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.7111 - loss: 0.5072 - val_accuracy: 0.7091 - val_loss: 0.4856
# Epoch 98/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.7178 - loss: 0.4889 - val_accuracy: 0.7114 - val_loss: 0.4866
# Epoch 99/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.6953 - loss: 0.5103 - val_accuracy: 0.7085 - val_loss: 0.4875
# Epoch 100/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7164 - loss: 0.4908 - val_accuracy: 0.7102 - val_loss: 0.4878
# Epoch 101/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.6945 - loss: 0.5056 - val_accuracy: 0.7179 - val_loss: 0.4847
# Epoch 102/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.7170 - loss: 0.4950 - val_accuracy: 0.7077 - val_loss: 0.4835
# Epoch 103/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.7065 - loss: 0.5015 - val_accuracy: 0.7319 - val_loss: 0.4822
# Epoch 104/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7261 - loss: 0.4932 - val_accuracy: 0.7151 - val_loss: 0.4830
# Epoch 105/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7116 - loss: 0.5018 - val_accuracy: 0.7301 - val_loss: 0.4824
# Epoch 106/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7215 - loss: 0.4954 - val_accuracy: 0.7157 - val_loss: 0.4819
# Epoch 107/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7070 - loss: 0.5024 - val_accuracy: 0.7196 - val_loss: 0.4800
# Epoch 108/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.6979 - loss: 0.5083 - val_accuracy: 0.7153 - val_loss: 0.4819
# Epoch 109/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.7122 - loss: 0.4946 - val_accuracy: 0.7112 - val_loss: 0.4801
# Epoch 110/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7192 - loss: 0.4887 - val_accuracy: 0.7165 - val_loss: 0.4847
# Epoch 111/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.7228 - loss: 0.4953 - val_accuracy: 0.7268 - val_loss: 0.4809
# Epoch 112/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7239 - loss: 0.4947 - val_accuracy: 0.7188 - val_loss: 0.4793
# Epoch 113/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7116 - loss: 0.4978 - val_accuracy: 0.7430 - val_loss: 0.4788
# Epoch 114/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7134 - loss: 0.5037 - val_accuracy: 0.7346 - val_loss: 0.4799
# Epoch 115/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7095 - loss: 0.4940 - val_accuracy: 0.7175 - val_loss: 0.4788
# Epoch 116/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7209 - loss: 0.4848 - val_accuracy: 0.7376 - val_loss: 0.4767
# Epoch 117/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7071 - loss: 0.4957 - val_accuracy: 0.7362 - val_loss: 0.4773
# Epoch 118/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7174 - loss: 0.4929 - val_accuracy: 0.7610 - val_loss: 0.4798
# Epoch 119/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7224 - loss: 0.4849 - val_accuracy: 0.7327 - val_loss: 0.4754
# Epoch 120/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.7230 - loss: 0.4839 - val_accuracy: 0.7151 - val_loss: 0.4779
# Epoch 121/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7147 - loss: 0.4910 - val_accuracy: 0.7413 - val_loss: 0.4762
# Epoch 122/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.7240 - loss: 0.4873 - val_accuracy: 0.7301 - val_loss: 0.4803
# Epoch 123/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7123 - loss: 0.4963 - val_accuracy: 0.7551 - val_loss: 0.4784
# Epoch 124/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.7144 - loss: 0.4902 - val_accuracy: 0.7331 - val_loss: 0.4773
# Epoch 125/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.7024 - loss: 0.4938 - val_accuracy: 0.7301 - val_loss: 0.4766
# Epoch 126/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7211 - loss: 0.4905 - val_accuracy: 0.7374 - val_loss: 0.4772
# Epoch 127/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7131 - loss: 0.4928 - val_accuracy: 0.7331 - val_loss: 0.4741
# Epoch 128/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7022 - loss: 0.4973 - val_accuracy: 0.7518 - val_loss: 0.4766
# Epoch 129/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.7259 - loss: 0.4813 - val_accuracy: 0.7255 - val_loss: 0.4740
# Epoch 130/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.7130 - loss: 0.4916 - val_accuracy: 0.7360 - val_loss: 0.4730
# Epoch 131/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.7206 - loss: 0.4820 - val_accuracy: 0.7303 - val_loss: 0.4750
# Epoch 132/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.7200 - loss: 0.4767 - val_accuracy: 0.7245 - val_loss: 0.4731
# Epoch 133/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7316 - loss: 0.4931 - val_accuracy: 0.7333 - val_loss: 0.4790
# Epoch 134/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7254 - loss: 0.4892 - val_accuracy: 0.7403 - val_loss: 0.4739
# Epoch 135/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.7211 - loss: 0.4892 - val_accuracy: 0.7200 - val_loss: 0.4724
# Epoch 136/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7100 - loss: 0.4958 - val_accuracy: 0.7270 - val_loss: 0.4752
# Epoch 137/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7185 - loss: 0.4805 - val_accuracy: 0.7300 - val_loss: 0.4707
# Epoch 138/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.7155 - loss: 0.4841 - val_accuracy: 0.7356 - val_loss: 0.4727
# Epoch 139/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7291 - loss: 0.4765 - val_accuracy: 0.7300 - val_loss: 0.4761
# Epoch 140/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7279 - loss: 0.4732 - val_accuracy: 0.7391 - val_loss: 0.4722
# Epoch 141/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7173 - loss: 0.4818 - val_accuracy: 0.7204 - val_loss: 0.4769
# Epoch 142/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7225 - loss: 0.4838 - val_accuracy: 0.7087 - val_loss: 0.4722
# Epoch 143/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7262 - loss: 0.4729 - val_accuracy: 0.7348 - val_loss: 0.4724
# Epoch 144/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7288 - loss: 0.4752 - val_accuracy: 0.7405 - val_loss: 0.4700
# Epoch 145/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.7241 - loss: 0.4810 - val_accuracy: 0.7169 - val_loss: 0.4738
# Epoch 146/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7222 - loss: 0.4860 - val_accuracy: 0.7387 - val_loss: 0.4671
# Epoch 147/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7108 - loss: 0.4868 - val_accuracy: 0.7395 - val_loss: 0.4712
# Epoch 148/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.7337 - loss: 0.4768 - val_accuracy: 0.7446 - val_loss: 0.4679
# Epoch 149/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.7403 - loss: 0.4700 - val_accuracy: 0.7085 - val_loss: 0.4715
# Epoch 150/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.7111 - loss: 0.4863 - val_accuracy: 0.7432 - val_loss: 0.4674
# Epoch 151/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.7219 - loss: 0.4836 - val_accuracy: 0.7561 - val_loss: 0.4716
# Epoch 152/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7331 - loss: 0.4819 - val_accuracy: 0.7374 - val_loss: 0.4680
# Epoch 153/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 0.7191 - loss: 0.4872 - val_accuracy: 0.7325 - val_loss: 0.4709
# Epoch 154/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7213 - loss: 0.4947 - val_accuracy: 0.7413 - val_loss: 0.4672
# Epoch 155/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.7282 - loss: 0.4816 - val_accuracy: 0.7664 - val_loss: 0.4684
# Epoch 156/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7268 - loss: 0.4802 - val_accuracy: 0.7401 - val_loss: 0.4659
# Epoch 157/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7048 - loss: 0.4886 - val_accuracy: 0.7323 - val_loss: 0.4656
# Epoch 158/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.7233 - loss: 0.4792 - val_accuracy: 0.7370 - val_loss: 0.4654
# Epoch 159/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.7341 - loss: 0.4721 - val_accuracy: 0.7374 - val_loss: 0.4637
# Epoch 160/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7390 - loss: 0.4710 - val_accuracy: 0.7380 - val_loss: 0.4649
# Epoch 161/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7289 - loss: 0.4738 - val_accuracy: 0.7553 - val_loss: 0.4644
# Epoch 162/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.7181 - loss: 0.4888 - val_accuracy: 0.7401 - val_loss: 0.4638
# Epoch 163/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7220 - loss: 0.4830 - val_accuracy: 0.7333 - val_loss: 0.4680
# Epoch 164/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7175 - loss: 0.4755 - val_accuracy: 0.7266 - val_loss: 0.4647
# Epoch 165/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.7233 - loss: 0.4862 - val_accuracy: 0.7434 - val_loss: 0.4655
# Epoch 166/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7426 - loss: 0.4654 - val_accuracy: 0.7401 - val_loss: 0.4627
# Epoch 167/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7264 - loss: 0.4712 - val_accuracy: 0.7169 - val_loss: 0.4662
# Epoch 168/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7348 - loss: 0.4724 - val_accuracy: 0.7446 - val_loss: 0.4691
# Epoch 169/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.7318 - loss: 0.4766 - val_accuracy: 0.7403 - val_loss: 0.4624
# Epoch 170/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7277 - loss: 0.4794 - val_accuracy: 0.7594 - val_loss: 0.4628
# Epoch 171/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.7392 - loss: 0.4879 - val_accuracy: 0.7415 - val_loss: 0.4640
# Epoch 172/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7348 - loss: 0.4759 - val_accuracy: 0.7229 - val_loss: 0.4638
# Epoch 173/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7325 - loss: 0.4763 - val_accuracy: 0.7442 - val_loss: 0.4670
# Epoch 174/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7213 - loss: 0.4838 - val_accuracy: 0.7227 - val_loss: 0.4639
# Epoch 175/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7324 - loss: 0.4706 - val_accuracy: 0.7368 - val_loss: 0.4652
# Epoch 176/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7243 - loss: 0.4756 - val_accuracy: 0.7608 - val_loss: 0.4597
# Epoch 177/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7335 - loss: 0.4863 - val_accuracy: 0.7147 - val_loss: 0.4705
# Epoch 178/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.7238 - loss: 0.4800 - val_accuracy: 0.7417 - val_loss: 0.4639
# Epoch 179/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.7370 - loss: 0.4676 - val_accuracy: 0.7409 - val_loss: 0.4610
# Epoch 180/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7288 - loss: 0.4737 - val_accuracy: 0.7541 - val_loss: 0.4638
# Epoch 181/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.7307 - loss: 0.4804 - val_accuracy: 0.7424 - val_loss: 0.4600
# Epoch 182/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.7432 - loss: 0.4672 - val_accuracy: 0.7422 - val_loss: 0.4630
# Epoch 183/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7366 - loss: 0.4654 - val_accuracy: 0.7659 - val_loss: 0.4586
# Epoch 184/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.7364 - loss: 0.4661 - val_accuracy: 0.7528 - val_loss: 0.4610
# Epoch 185/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.7381 - loss: 0.4671 - val_accuracy: 0.7424 - val_loss: 0.4652
# Epoch 186/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7312 - loss: 0.4699 - val_accuracy: 0.7430 - val_loss: 0.4572
# Epoch 187/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7255 - loss: 0.4820 - val_accuracy: 0.7604 - val_loss: 0.4599
# Epoch 188/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7375 - loss: 0.4712 - val_accuracy: 0.7471 - val_loss: 0.4602
# Epoch 189/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7342 - loss: 0.4734 - val_accuracy: 0.7364 - val_loss: 0.4620
# Epoch 190/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.7219 - loss: 0.4745 - val_accuracy: 0.7161 - val_loss: 0.4717
# Epoch 191/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.7272 - loss: 0.4781 - val_accuracy: 0.7352 - val_loss: 0.4584
# Epoch 192/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7263 - loss: 0.4766 - val_accuracy: 0.7623 - val_loss: 0.4581
# Epoch 193/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7355 - loss: 0.4714 - val_accuracy: 0.7668 - val_loss: 0.4564
# Epoch 194/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7513 - loss: 0.4609 - val_accuracy: 0.7348 - val_loss: 0.4586
# Epoch 195/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7432 - loss: 0.4639 - val_accuracy: 0.7409 - val_loss: 0.4561
# Epoch 196/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7299 - loss: 0.4733 - val_accuracy: 0.7419 - val_loss: 0.4590
# Epoch 197/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7361 - loss: 0.4718 - val_accuracy: 0.7639 - val_loss: 0.4591
# Epoch 198/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.7374 - loss: 0.4644 - val_accuracy: 0.7428 - val_loss: 0.4637
# Epoch 199/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.7228 - loss: 0.4676 - val_accuracy: 0.7620 - val_loss: 0.4563
# Epoch 200/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7339 - loss: 0.4738 - val_accuracy: 0.7629 - val_loss: 0.4551
# Epoch 201/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7423 - loss: 0.4672 - val_accuracy: 0.7422 - val_loss: 0.4626
# Epoch 202/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.7271 - loss: 0.4794 - val_accuracy: 0.7637 - val_loss: 0.4551
# Epoch 203/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7379 - loss: 0.4811 - val_accuracy: 0.7417 - val_loss: 0.4574
# Epoch 204/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.7350 - loss: 0.4655 - val_accuracy: 0.7678 - val_loss: 0.4549
# Epoch 205/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7353 - loss: 0.4709 - val_accuracy: 0.7538 - val_loss: 0.4560
# Epoch 206/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7366 - loss: 0.4713 - val_accuracy: 0.7469 - val_loss: 0.4585
# Epoch 207/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7262 - loss: 0.4807 - val_accuracy: 0.7577 - val_loss: 0.4570
# Epoch 208/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7467 - loss: 0.4631 - val_accuracy: 0.7348 - val_loss: 0.4622
# Epoch 209/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.7344 - loss: 0.4702 - val_accuracy: 0.7582 - val_loss: 0.4533
# Epoch 210/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7372 - loss: 0.4733 - val_accuracy: 0.7409 - val_loss: 0.4538
# Epoch 211/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.7526 - loss: 0.4545 - val_accuracy: 0.7664 - val_loss: 0.4537
# Epoch 212/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7417 - loss: 0.4669 - val_accuracy: 0.7409 - val_loss: 0.4557
# Epoch 213/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.7255 - loss: 0.4708 - val_accuracy: 0.7559 - val_loss: 0.4566
# Epoch 214/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.7290 - loss: 0.4792 - val_accuracy: 0.7420 - val_loss: 0.4525
# Epoch 215/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7501 - loss: 0.4573 - val_accuracy: 0.7432 - val_loss: 0.4522
# Epoch 216/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.7337 - loss: 0.4698 - val_accuracy: 0.7618 - val_loss: 0.4517
# Epoch 217/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.7526 - loss: 0.4465 - val_accuracy: 0.7493 - val_loss: 0.4551
# Epoch 218/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.7319 - loss: 0.4775 - val_accuracy: 0.7149 - val_loss: 0.4650
# Epoch 219/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.7275 - loss: 0.4692 - val_accuracy: 0.7210 - val_loss: 0.4595
# Epoch 220/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.7326 - loss: 0.4648 - val_accuracy: 0.7534 - val_loss: 0.4521
# Epoch 221/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7288 - loss: 0.4799 - val_accuracy: 0.7526 - val_loss: 0.4532
# Epoch 222/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.7488 - loss: 0.4523 - val_accuracy: 0.7434 - val_loss: 0.4544
# Epoch 223/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.7374 - loss: 0.4708 - val_accuracy: 0.7598 - val_loss: 0.4545
# Epoch 224/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.7284 - loss: 0.4736 - val_accuracy: 0.7530 - val_loss: 0.4533
# Epoch 225/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.7390 - loss: 0.4708 - val_accuracy: 0.7393 - val_loss: 0.4543
# Epoch 226/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.7263 - loss: 0.4698 - val_accuracy: 0.7649 - val_loss: 0.4566
# Epoch 227/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7337 - loss: 0.4659 - val_accuracy: 0.7444 - val_loss: 0.4599
# Epoch 228/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7378 - loss: 0.4710 - val_accuracy: 0.7385 - val_loss: 0.4574
# Epoch 229/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.7419 - loss: 0.4629 - val_accuracy: 0.7538 - val_loss: 0.4570
# Epoch 230/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.7267 - loss: 0.4675 - val_accuracy: 0.7428 - val_loss: 0.4567
# Epoch 231/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7315 - loss: 0.4766 - val_accuracy: 0.7422 - val_loss: 0.4527
# Epoch 232/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.7315 - loss: 0.4778 - val_accuracy: 0.7487 - val_loss: 0.4618
# Epoch 233/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7334 - loss: 0.4626 - val_accuracy: 0.7450 - val_loss: 0.4540
# Epoch 234/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7250 - loss: 0.4750 - val_accuracy: 0.7629 - val_loss: 0.4584
# Epoch 235/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7296 - loss: 0.4690 - val_accuracy: 0.7415 - val_loss: 0.4509
# Epoch 236/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.7275 - loss: 0.4665 - val_accuracy: 0.7346 - val_loss: 0.4556
# Epoch 237/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.7297 - loss: 0.4733 - val_accuracy: 0.7417 - val_loss: 0.4522
# Epoch 238/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7301 - loss: 0.4680 - val_accuracy: 0.7411 - val_loss: 0.4509
# Epoch 239/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7409 - loss: 0.4630 - val_accuracy: 0.7606 - val_loss: 0.4519
# Epoch 240/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.7251 - loss: 0.4701 - val_accuracy: 0.7356 - val_loss: 0.4560
# Epoch 241/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.7336 - loss: 0.4644 - val_accuracy: 0.7551 - val_loss: 0.4473
# Epoch 242/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7504 - loss: 0.4556 - val_accuracy: 0.7424 - val_loss: 0.4475
# Epoch 243/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7465 - loss: 0.4517 - val_accuracy: 0.7643 - val_loss: 0.4460
# Epoch 244/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.7340 - loss: 0.4698 - val_accuracy: 0.7497 - val_loss: 0.4505
# Epoch 245/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7266 - loss: 0.4753 - val_accuracy: 0.7614 - val_loss: 0.4474
# Epoch 246/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.7283 - loss: 0.4712 - val_accuracy: 0.7555 - val_loss: 0.4516
# Epoch 247/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.7343 - loss: 0.4549 - val_accuracy: 0.7417 - val_loss: 0.4519
# Epoch 248/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.7437 - loss: 0.4550 - val_accuracy: 0.7612 - val_loss: 0.4495
# Epoch 249/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.7334 - loss: 0.4762 - val_accuracy: 0.7666 - val_loss: 0.4509
# Epoch 250/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7485 - loss: 0.4590 - val_accuracy: 0.7536 - val_loss: 0.4480
# Epoch 251/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.7484 - loss: 0.4650 - val_accuracy: 0.7635 - val_loss: 0.4470
# Epoch 252/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.4577 - val_accuracy: 0.7549 - val_loss: 0.4488
# Epoch 253/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7388 - loss: 0.4650 - val_accuracy: 0.7528 - val_loss: 0.4480
# Epoch 254/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7460 - loss: 0.4684 - val_accuracy: 0.7543 - val_loss: 0.4494
# Epoch 255/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.7263 - loss: 0.4659 - val_accuracy: 0.7424 - val_loss: 0.4500
# Epoch 256/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.7253 - loss: 0.4801 - val_accuracy: 0.7426 - val_loss: 0.4507
# Epoch 257/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7369 - loss: 0.4679 - val_accuracy: 0.7188 - val_loss: 0.4568
# Epoch 258/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.7410 - loss: 0.4549 - val_accuracy: 0.7700 - val_loss: 0.4453
# Epoch 259/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.7330 - loss: 0.4652 - val_accuracy: 0.7424 - val_loss: 0.4483
# Epoch 260/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.7424 - loss: 0.4564 - val_accuracy: 0.7621 - val_loss: 0.4470
# Epoch 261/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7530 - loss: 0.4474 - val_accuracy: 0.7407 - val_loss: 0.4461
# Epoch 262/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.7498 - loss: 0.4530 - val_accuracy: 0.7629 - val_loss: 0.4457
# Epoch 263/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.7433 - loss: 0.4564 - val_accuracy: 0.7417 - val_loss: 0.4469
# Epoch 264/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7581 - loss: 0.4462 - val_accuracy: 0.7623 - val_loss: 0.4432
# Epoch 265/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.7408 - loss: 0.4440 - val_accuracy: 0.7534 - val_loss: 0.4496
# Epoch 266/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7420 - loss: 0.4614 - val_accuracy: 0.7664 - val_loss: 0.4443
# Epoch 267/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.7487 - loss: 0.4455 - val_accuracy: 0.7397 - val_loss: 0.4492
# Epoch 268/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7406 - loss: 0.4572 - val_accuracy: 0.7625 - val_loss: 0.4530
# Epoch 269/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.7357 - loss: 0.4741 - val_accuracy: 0.7356 - val_loss: 0.4519
# Epoch 270/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.7444 - loss: 0.4650 - val_accuracy: 0.7448 - val_loss: 0.4469
# Epoch 271/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.7281 - loss: 0.4645 - val_accuracy: 0.7666 - val_loss: 0.4440
# Epoch 272/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7443 - loss: 0.4628 - val_accuracy: 0.7440 - val_loss: 0.4478
# Epoch 273/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.7417 - loss: 0.4703 - val_accuracy: 0.7569 - val_loss: 0.4439
# Epoch 274/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.7410 - loss: 0.4569 - val_accuracy: 0.7417 - val_loss: 0.4478
# Epoch 275/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7475 - loss: 0.4601 - val_accuracy: 0.7614 - val_loss: 0.4429
# Epoch 276/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7429 - loss: 0.4480 - val_accuracy: 0.7526 - val_loss: 0.4480
# Epoch 277/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.7415 - loss: 0.4580 - val_accuracy: 0.7592 - val_loss: 0.4481
# Epoch 278/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.7319 - loss: 0.4651 - val_accuracy: 0.7645 - val_loss: 0.4406
# Epoch 279/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.7394 - loss: 0.4573 - val_accuracy: 0.7356 - val_loss: 0.4517
# Epoch 280/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.7366 - loss: 0.4638 - val_accuracy: 0.7694 - val_loss: 0.4447
# Epoch 281/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7438 - loss: 0.4526 - val_accuracy: 0.7444 - val_loss: 0.4461
# Epoch 282/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.7337 - loss: 0.4567 - val_accuracy: 0.7690 - val_loss: 0.4426
# Epoch 283/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.7360 - loss: 0.4548 - val_accuracy: 0.7506 - val_loss: 0.4487
# Epoch 284/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.7094 - loss: 0.4810 - val_accuracy: 0.7678 - val_loss: 0.4456
# Epoch 285/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.7407 - loss: 0.4681 - val_accuracy: 0.7440 - val_loss: 0.4443
# Epoch 286/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.7406 - loss: 0.4631 - val_accuracy: 0.7397 - val_loss: 0.4451
# Epoch 287/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.7331 - loss: 0.4663 - val_accuracy: 0.7348 - val_loss: 0.4523
# Epoch 288/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.7360 - loss: 0.4637 - val_accuracy: 0.7487 - val_loss: 0.4457
# Epoch 289/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7414 - loss: 0.4640 - val_accuracy: 0.7645 - val_loss: 0.4459
# Epoch 290/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.7492 - loss: 0.4639 - val_accuracy: 0.7541 - val_loss: 0.4468
# Epoch 291/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.7325 - loss: 0.4539 - val_accuracy: 0.7452 - val_loss: 0.4478
# Epoch 292/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7365 - loss: 0.4616 - val_accuracy: 0.7458 - val_loss: 0.4454
# Epoch 293/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.7367 - loss: 0.4674 - val_accuracy: 0.7376 - val_loss: 0.4531
# Epoch 294/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.7372 - loss: 0.4590 - val_accuracy: 0.7424 - val_loss: 0.4465
# Epoch 295/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.7437 - loss: 0.4588 - val_accuracy: 0.7473 - val_loss: 0.4474
# Epoch 296/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7455 - loss: 0.4566 - val_accuracy: 0.7571 - val_loss: 0.4438
# Epoch 297/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.7407 - loss: 0.4573 - val_accuracy: 0.7596 - val_loss: 0.4422
# Epoch 298/300
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7378 - loss: 0.4619 - val_accuracy: 0.7413 - val_loss: 0.4425
# Epoch 298: early stopping

# %% [markdown]
# Let's plot the Loss vs Epoch chart.

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %% [markdown]
# Let's evaluate the trained model.

# %%
print("Loss, Accuracy: ", model.evaluate(X_test, y_cat_test))
# Out:
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - accuracy: 0.7499 - loss: 0.4356
# Loss, Accuracy:  [0.4424957036972046, 0.7412682771682739]

# %%
print("F1-score: ", f1_score(y_test, np.argmax(model.predict(X_test), axis=1), average='weighted'))
# Out:
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step
# F1-score:  0.71761028436349

# %% [markdown]
# With a simple NN model a F1-score of approximately 70% was achieved.
#
# There is always room for model fine-tuning, optimizations and futher model improvements.
