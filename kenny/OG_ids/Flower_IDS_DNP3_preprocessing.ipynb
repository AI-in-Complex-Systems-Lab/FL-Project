# %% [markdown]
# # Federated Learning with Flower

# %% [markdown]
# #### This notebook presents a simple Federated Learning example / application on developing a Machine Learning model as an Intrusion Detection System for defending against Cyberattacks using distributed and private data.
# #### This example uses Docker containers as independent workers / clients for performing the client model training on the limited and private local client data.
# #### This example was developed as part of the research conducted at [MetaMind Innovations - MINDS](https://metamind.gr/) in the framework of the [ELECTRON H2020](https://metamind.gr/project/electron-h2020/) project.

# %% [markdown]
# ### This notebook, as well as the Flower example, were implemented and tested using Python v3.11, Flower v1.5 and TensorFlow v2.14.1

# %% [markdown]
# ## Set Up Flower Environment

# %%
# !pip install --quiet --upgrade flwr==1.5.0
# !pip install --quiet --upgrade tensorflow-cpu==2.14.1
# !pip install --quiet --upgrade scikit-learn
# !pip install --quiet --upgrade pandas
# !pip install --quiet --upgrade matplotlib
# !pip install --quiet --upgrade git+https://github.com/nepiskopos/py7zr.git

# %% [markdown]
# ## Dataset

# %% [markdown]
# This dataset is part of the [DNP3 Intrusion Detection Dataset](https://ieee-dataport.org/documents/dnp3-intrusion-detection-dataset) -- DOI: [10.21227/s7h0-b081](https://dx.doi.org/10.21227/s7h0-b081) -- published by [ITHACA – University of Western Macedonia](http://ithaca.ece.uowm.gr/).

# %%
import errno
import os
import py7zr
import re
import shutil
import sys
import time
import urllib


def reporthook(count, block_size, total_size):
    global start_time
    if count == 0:
        start_time = time.time()
        return
    duration = time.time() - start_time
    progress_size = int(count * block_size)
    speed = int(progress_size / (1024 * duration))
    percent = int(count * block_size * 100 / total_size)
    sys.stdout.write("\r...%d%%, %d MB, %d KB/s, %d seconds passed" %
                    (percent, progress_size / (1024 * 1024), speed, duration))
    sys.stdout.flush()

def download(url, filename):
    urllib.request.urlretrieve(url, filename, reporthook)

def extract(archive, target_dir):
    archive = py7zr.SevenZipFile(archive, mode='r')
    try:
        os.makedirs(target_dir)
        
        archive.extractall(path=target_dir)
        archive.close()
        
        print(f"Archive '{archive}' extracted successfully!")
    except OSError as e:
        if e.errno == errno.EEXIST:
            archive.extractall(path=target_dir)
            archive.close()
            
            print(f"Archive '{archive}' extracted successfully!")
        else:
            print(f"Archive '{archive}' failed to extract...")


base_data_dir = './datasets'

if not os.path.isdir(os.path.join(base_data_dir, 'Training_Testing_Balanced_CSV_Files')):
    filename = 'DNP3_Intrusion_Detection_Dataset_Final.7z'
    
    if not py7zr.is_7zfile(filename):
        url = ('https://zenodo.org/records/7348493/files/DNP3_Intrusion_Detection_Dataset_Final.7z?download=1')
        download(url, filename)
    
    extract(filename, base_data_dir)

    innerDirs = os.listdir(base_data_dir)
    for dir in innerDirs:
        if (re.search('2020*', dir)):
            shutil.rmtree(os.path.join(base_data_dir, dir))
    
    os.remove(os.path.join('.', filename))

# %%
import collections
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

pd.set_option('future.no_silent_downcasting', True)

# %matplotlib inline

# %% [markdown]
# We must choose which dataset version to facilitate for the experimentation.
#
# We must also choose $3 \leq N \leq 5$ distinct federated learning workers.
#
# For this example we use the CICFlowMeter dataset with 3 workers.

# %%
tp = 'cic'      # Type: dataset type (CICFlowMeter or Custom Python parser), choose between 'cic' and 'custom'
n_workers = 3   # N: number of federated workers, choose between 3 and 5

# %% [markdown]
# Perform some value checks

# %%
assert tp in ('cic', 'custom'), "Wrong dataset type, choose between 'cic' and 'custom'"
assert n_workers in (3, 4, 5), "Wrong number of workers, choose between 3 and 5"

# %%
path = os.path.join(base_data_dir, 'Training_Testing_Balanced_CSV_Files')

if tp == 'cic':
    dataset = f'CICFlowMeter'
else:
    dataset = 'Custom_DNP3_Parser'

if 'CIC' in dataset:
    n = dataset.split('_')[-1]
    train_csv = os.path.join(os.path.join(path, dataset), f'CICFlowMeter_Training_Balanced.csv')
    test_csv = os.path.join(os.path.join(path, dataset), f'CICFlowMeter_Testing_Balanced.csv')
elif 'Custom' in dataset:
    n = dataset.split('_')
    train_csv = os.path.join(os.path.join(path, dataset), f'Custom_DNP3_Parser_Training_Balanced.csv')
    test_csv = os.path.join(os.path.join(path, dataset), f'Custom_DNP3_Parser_Testing_Balanced.csv')
else:
    raise Exception("Wrong dataset")

df_train = pd.read_csv(train_csv, sep=r'\s*,\s*', header=0, 
                       encoding='ascii', engine='python')
df_test = pd.read_csv(train_csv, sep=r'\s*,\s*', header=0, 
                      encoding='ascii', engine='python')

# %% [markdown]
# Let's perform some data exploration.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 86 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       5126 non-null   int64
#  1   Unnamed: 0         5126 non-null   int64
#  2   Flow ID            5126 non-null   object
#  3   Src IP             5126 non-null   object
#  4   Src Port           5126 non-null   int64
#  5   Dst IP             5126 non-null   object
#  6   Dst Port           5126 non-null   int64
#  7   Protocol           5126 non-null   int64
#  8   Timestamp          5126 non-null   object
#  9   Flow Duration      5126 non-null   int64
#  10  Tot Fwd Pkts       5126 non-null   int64
#  11  Tot Bwd Pkts       5126 non-null   int64
#  12  TotLen Fwd Pkts    5126 non-null   float64
#  13  TotLen Bwd Pkts    5126 non-null   float64
#  14  Fwd Pkt Len Max    5126 non-null   float64
#  15  Fwd Pkt Len Min    5126 non-null   float64
#  16  Fwd Pkt Len Mean   5126 non-null   float64
#  17  Fwd Pkt Len Std    5126 non-null   float64
#  18  Bwd Pkt Len Max    5126 non-null   float64
#  19  Bwd Pkt Len Min    5126 non-null   float64
#  20  Bwd Pkt Len Mean   5126 non-null   float64
#  21  Bwd Pkt Len Std    5126 non-null   float64
#  22  Flow Byts/s        5126 non-null   float64
#  23  Flow Pkts/s        5126 non-null   float64
#  24  Flow IAT Mean      5126 non-null   float64
#  25  Flow IAT Std       5126 non-null   float64
#  26  Flow IAT Max       5126 non-null   float64
#  27  Flow IAT Min       5126 non-null   float64
#  28  Fwd IAT Tot        5126 non-null   float64
#  29  Fwd IAT Mean       5126 non-null   float64
#  30  Fwd IAT Std        5126 non-null   float64
#  31  Fwd IAT Max        5126 non-null   float64
#  32  Fwd IAT Min        5126 non-null   float64
#  33  Bwd IAT Tot        5126 non-null   float64
#  34  Bwd IAT Mean       5126 non-null   float64
#  35  Bwd IAT Std        5126 non-null   float64
#  36  Bwd IAT Max        5126 non-null   float64
#  37  Bwd IAT Min        5126 non-null   float64
#  38  Fwd PSH Flags      5126 non-null   int64
#  39  Bwd PSH Flags      5126 non-null   int64
#  40  Fwd URG Flags      5126 non-null   int64
#  41  Bwd URG Flags      5126 non-null   int64
#  42  Fwd Header Len     5126 non-null   int64
#  43  Bwd Header Len     5126 non-null   int64
#  44  Fwd Pkts/s         5126 non-null   float64
#  45  Bwd Pkts/s         5126 non-null   float64
#  46  Pkt Len Min        5126 non-null   float64
#  47  Pkt Len Max        5126 non-null   float64
#  48  Pkt Len Mean       5126 non-null   float64
#  49  Pkt Len Std        5126 non-null   float64
#  50  Pkt Len Var        5126 non-null   float64
#  51  FIN Flag Cnt       5126 non-null   int64
#  52  SYN Flag Cnt       5126 non-null   int64
#  53  RST Flag Cnt       5126 non-null   int64
#  54  PSH Flag Cnt       5126 non-null   int64
#  55  ACK Flag Cnt       5126 non-null   int64
#  56  URG Flag Cnt       5126 non-null   int64
#  57  CWE Flag Count     5126 non-null   int64
#  58  ECE Flag Cnt       5126 non-null   int64
#  59  Down/Up Ratio      5126 non-null   float64
#  60  Pkt Size Avg       5126 non-null   float64
#  61  Fwd Seg Size Avg   5126 non-null   float64
#  62  Bwd Seg Size Avg   5126 non-null   float64
#  63  Fwd Byts/b Avg     5126 non-null   int64
#  64  Fwd Pkts/b Avg     5126 non-null   int64
#  65  Fwd Blk Rate Avg   5126 non-null   int64
#  66  Bwd Byts/b Avg     5126 non-null   int64
#  67  Bwd Pkts/b Avg     5126 non-null   int64
#  68  Bwd Blk Rate Avg   5126 non-null   int64
#  69  Subflow Fwd Pkts   5126 non-null   int64
#  70  Subflow Fwd Byts   5126 non-null   int64
#  71  Subflow Bwd Pkts   5126 non-null   int64
#  72  Subflow Bwd Byts   5126 non-null   int64
#  73  Init Fwd Win Byts  5126 non-null   int64
#  74  Init Bwd Win Byts  5126 non-null   int64
#  75  Fwd Act Data Pkts  5126 non-null   int64
#  76  Fwd Seg Size Min   5126 non-null   int64
#  77  Active Mean        5126 non-null   float64
#  78  Active Std         5126 non-null   float64
#  79  Active Max         5126 non-null   float64
#  80  Active Min         5126 non-null   float64
#  81  Idle Mean          5126 non-null   float64
#  82  Idle Std           5126 non-null   float64
#  83  Idle Max           5126 non-null   float64
#  84  Idle Min           5126 non-null   float64
#  85  Label              5126 non-null   object
# dtypes: float64(45), int64(36), object(5)
# memory usage: 3.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 86 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       5126 non-null   int64
#  1   Unnamed: 0         5126 non-null   int64
#  2   Flow ID            5126 non-null   object
#  3   Src IP             5126 non-null   object
#  4   Src Port           5126 non-null   int64
#  5   Dst IP             5126 non-null   object
#  6   Dst Port           5126 non-null   int64
#  7   Protocol           5126 non-null   int64
#  8   Timestamp          5126 non-null   object
#  9   Flow Duration      5126 non-null   int64
#  10  Tot Fwd Pkts       5126 non-null   int64
#  11  Tot Bwd Pkts       5126 non-null   int64
#  12  TotLen Fwd Pkts    5126 non-null   float64
#  13  TotLen Bwd Pkts    5126 non-null   float64
#  14  Fwd Pkt Len Max    5126 non-null   float64
#  15  Fwd Pkt Len Min    5126 non-null   float64
#  16  Fwd Pkt Len Mean   5126 non-null   float64
#  17  Fwd Pkt Len Std    5126 non-null   float64
#  18  Bwd Pkt Len Max    5126 non-null   float64
#  19  Bwd Pkt Len Min    5126 non-null   float64
#  20  Bwd Pkt Len Mean   5126 non-null   float64
#  21  Bwd Pkt Len Std    5126 non-null   float64
#  22  Flow Byts/s        5126 non-null   float64
#  23  Flow Pkts/s        5126 non-null   float64
#  24  Flow IAT Mean      5126 non-null   float64
#  25  Flow IAT Std       5126 non-null   float64
#  26  Flow IAT Max       5126 non-null   float64
#  27  Flow IAT Min       5126 non-null   float64
#  28  Fwd IAT Tot        5126 non-null   float64
#  29  Fwd IAT Mean       5126 non-null   float64
#  30  Fwd IAT Std        5126 non-null   float64
#  31  Fwd IAT Max        5126 non-null   float64
#  32  Fwd IAT Min        5126 non-null   float64
#  33  Bwd IAT Tot        5126 non-null   float64
#  34  Bwd IAT Mean       5126 non-null   float64
#  35  Bwd IAT Std        5126 non-null   float64
#  36  Bwd IAT Max        5126 non-null   float64
#  37  Bwd IAT Min        5126 non-null   float64
#  38  Fwd PSH Flags      5126 non-null   int64
#  39  Bwd PSH Flags      5126 non-null   int64
#  40  Fwd URG Flags      5126 non-null   int64
#  41  Bwd URG Flags      5126 non-null   int64
#  42  Fwd Header Len     5126 non-null   int64
#  43  Bwd Header Len     5126 non-null   int64
#  44  Fwd Pkts/s         5126 non-null   float64
#  45  Bwd Pkts/s         5126 non-null   float64
#  46  Pkt Len Min        5126 non-null   float64
#  47  Pkt Len Max        5126 non-null   float64
#  48  Pkt Len Mean       5126 non-null   float64
#  49  Pkt Len Std        5126 non-null   float64
#  50  Pkt Len Var        5126 non-null   float64
#  51  FIN Flag Cnt       5126 non-null   int64
#  52  SYN Flag Cnt       5126 non-null   int64
#  53  RST Flag Cnt       5126 non-null   int64
#  54  PSH Flag Cnt       5126 non-null   int64
#  55  ACK Flag Cnt       5126 non-null   int64
#  56  URG Flag Cnt       5126 non-null   int64
#  57  CWE Flag Count     5126 non-null   int64
#  58  ECE Flag Cnt       5126 non-null   int64
#  59  Down/Up Ratio      5126 non-null   float64
#  60  Pkt Size Avg       5126 non-null   float64
#  61  Fwd Seg Size Avg   5126 non-null   float64
#  62  Bwd Seg Size Avg   5126 non-null   float64
#  63  Fwd Byts/b Avg     5126 non-null   int64
#  64  Fwd Pkts/b Avg     5126 non-null   int64
#  65  Fwd Blk Rate Avg   5126 non-null   int64
#  66  Bwd Byts/b Avg     5126 non-null   int64
#  67  Bwd Pkts/b Avg     5126 non-null   int64
#  68  Bwd Blk Rate Avg   5126 non-null   int64
#  69  Subflow Fwd Pkts   5126 non-null   int64
#  70  Subflow Fwd Byts   5126 non-null   int64
#  71  Subflow Bwd Pkts   5126 non-null   int64
#  72  Subflow Bwd Byts   5126 non-null   int64
#  73  Init Fwd Win Byts  5126 non-null   int64
#  74  Init Bwd Win Byts  5126 non-null   int64
#  75  Fwd Act Data Pkts  5126 non-null   int64
#  76  Fwd Seg Size Min   5126 non-null   int64
#  77  Active Mean        5126 non-null   float64
#  78  Active Std         5126 non-null   float64
#  79  Active Max         5126 non-null   float64
#  80  Active Min         5126 non-null   float64
#  81  Idle Mean          5126 non-null   float64
#  82  Idle Std           5126 non-null   float64
#  83  Idle Max           5126 non-null   float64
#  84  Idle Min           5126 non-null   float64
#  85  Label              5126 non-null   object
# dtypes: float64(45), int64(36), object(5)
# memory usage: 3.4+ MB

# %% [markdown]
# As a preprocessing step, we transorm the "Label" feature from string to categorical and then to numeric.

# %%
df_train['Label'] = df_train['Label'].str.lower()
df_test['Label'] = df_test['Label'].str.lower()

unique_labels = list(df_train.Label.astype('category').unique())
unique_codes = list(df_train.Label.astype('category').cat.codes.unique())

mapping = dict(zip(unique_labels, unique_codes))
mapping_inv = dict(zip(unique_codes, unique_labels))

# %%
mapping
# Out:
# {'init_data': 5,
#  'disable_unsolicited': 2,
#  'warm_restart': 10,
#  'mitm_dos': 6,
#  'arp_poisoning': 0,
#  'normal': 7,
#  'dnp3_enumerate': 3,
#  'cold_restart': 1,
#  'dnp3_info': 4,
#  'replay': 8,
#  'stop_app': 9}

# %%
df_train['Label'] = df_train['Label'].astype('category').cat.rename_categories(mapping)
df_test['Label'] = df_test['Label'].astype('category').cat.rename_categories(mapping)

# %% [markdown]
# Now, we remove the features which do not assist with training a ML model.

# %%
train = df_train.iloc[:,9:]
test = df_test.iloc[:,9:]

# %% [markdown]
# We rename the "Label" column to "y".

# %%
train.rename(columns={"Label": "y"}, inplace=True, errors="raise")
test.rename(columns={"Label": "y"}, inplace=True, errors="raise")

# %% [markdown]
# We drop Inf and NaN values both in the training and in test feature data.

# %%
# Replace Inf values with NaN
train.replace([np.inf, -np.inf], np.nan, inplace=True)
test.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN values
train.dropna(inplace=True)
test.dropna(inplace=True)

# %% [markdown]
# We store the modified datasets into new local CSV files for future use and model evaluation.

# %%
directory = os.path.join(base_data_dir, 'federated_datasets')

try:
    os.makedirs(directory)
    train.to_csv(os.path.join(directory, 'train_data.csv'), index=False)
    test.to_csv(os.path.join(directory, 'test_data.csv'), index=False)
except OSError as e:
    if e.errno != errno.EEXIST:
        raise
    else:   
        train.to_csv(os.path.join(directory, 'train_data.csv'), index=False)
        test.to_csv(os.path.join(directory, 'test_data.csv'), index=False)

# %% [markdown]
# Each worker will be assigned a subset of the dataset with $\lfloor {M \over N} \rfloor$ data points.
#
# Each worker data is stored as a seperate CSV file with the proper naming scheme.

# %%
n_samples = int(train.shape[0] / n_workers)

assert type(n_workers) == int, "Non-int number of workers"
assert n_workers >= 3 and n_workers <= df_train.shape[0], "At least 3 workers and at most as many workers as the number of samples are allowed"
assert n_samples > 0, "Each worker must be assigned at least one data point"

# %%
client_data = []
train_copy = train.copy()

for i in range(n_workers):
    sample = train_copy.sample(n=n_samples)
    sample.to_csv(os.path.join(directory, f'client_train_data_{i+1}.csv'), index=False)
    train_copy.drop(index=sample.index, inplace=True)
    client_data.append(sample)

# %% [markdown]
# Let's check the number of points in each straggler's training data.

# %%
for i in range(n_workers):
    print(f"Worker {i+1} training data contains {len(client_data[i])} points")
# Out:
# Worker 1 training data contains 1708 points
# Worker 2 training data contains 1708 points
# Worker 3 training data contains 1708 points

# %% [markdown]
# Let's perform some statistical analysis on the difference in the number of samples for each digit in each client dataset.

# %%
# Number of examples per layer for a sample of clients
fig = plt.figure(figsize=(20, 7))
fig.suptitle('Label Counts for a Sample of Worker Data')
fig.tight_layout()

for i in range(n_workers):
    m = 0
    plot_data = collections.defaultdict(list)
    sample = client_data[i]
    for label in sample['y']:
        # Append counts individually per label to make plots
        # more colorful instead of one color per plot.
        plot_data[label].append(label)
        m = max(m, len(plot_data[label]))
    
    n_cols = n_workers if n_workers < 5 else 5
    xlim = [0, m+(20-m%20)]
    ylim = [min(unique_codes)-1, max(unique_codes)+1]
    yticks = list(range(min(unique_codes), max(unique_codes)+1))
    yticks_labels = [mapping_inv[k] for k in range(0, max(unique_codes)+1)]
    
    plt.subplot(int(n_workers / 5)+1, n_cols, i+1)
    plt.subplots_adjust(wspace=0.3)
    plt.title('Worker {}'.format(i+1))
    plt.xlabel('#points')
    plt.xlim(xlim)
    plt.ylabel('Label')
    plt.ylim(ylim)
    plt.yticks(yticks, labels=yticks_labels)
    
    # plot values on top of bars
    for key in plot_data:
        if len(plot_data[key]) > 0:
            plt.text(len(plot_data[key])+8, int(key)-0.1, str(len(plot_data[key])), ha='center')
    
    for j in range(min(unique_codes),max(unique_codes)+1):
        plt.hist(
            plot_data[j],
            density=False,
            bins=[k-0.5 for k in range(min(unique_codes),max(unique_codes)+2)],
            orientation='horizontal'
        )

# %% [markdown]
# ## Centralized model

# %% [markdown]
# Let's train a centralized IDS model to use as a reference.

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
# Out:
# 2024-04-29 16:53:50.160830: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-29 16:53:50.179456: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# We have to scale the data to avoid huge value deviations.

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(train.drop(['y'], axis=1).to_numpy())
y_train = train['y'].to_numpy()
X_test = scaler.transform(test.drop(['y'], axis=1).to_numpy())
y_test = test['y'].to_numpy()

# %% [markdown]
# Then, we are better off using one-hot-vectors than scalars for the label representation.

# %%
y_cat_train = to_categorical(y_train)
y_cat_test = to_categorical(y_test)

# %% [markdown]
# We define a MLP model with one hidden layer.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(units=50, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=y_cat_test.shape[1], activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# We use early stopping monitoring the validation loss to avoid overfitting.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# %% [markdown]
# Let's train the model.

# %%
model.fit(
    x=X_train, 
    y=y_cat_train, 
    epochs=300,
    validation_data=(X_test, y_cat_test),
    verbose=1,
    batch_size=64,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/300
# 81/81 [==============================] - 1s 4ms/step - loss: 1.6813 - accuracy: 0.3762 - val_loss: 1.2360 - val_accuracy: 0.5042
# Epoch 2/300
# 81/81 [==============================] - 0s 3ms/step - loss: 1.2060 - accuracy: 0.4991 - val_loss: 1.0905 - val_accuracy: 0.5138
# Epoch 3/300
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1139 - accuracy: 0.5218 - val_loss: 1.0460 - val_accuracy: 0.6002
# Epoch 4/300
# 81/81 [==============================] - 0s 3ms/step - loss: 1.0774 - accuracy: 0.5366 - val_loss: 1.0095 - val_accuracy: 0.6919
# Epoch 5/300
# 81/81 [==============================] - 0s 3ms/step - loss: 1.0327 - accuracy: 0.5557 - val_loss: 0.9718 - val_accuracy: 0.6763
# Epoch 6/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.9931 - accuracy: 0.5852 - val_loss: 0.9343 - val_accuracy: 0.6021
# Epoch 7/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.9497 - accuracy: 0.6045 - val_loss: 0.8932 - val_accuracy: 0.6911
# Epoch 8/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9110 - accuracy: 0.6137 - val_loss: 0.8535 - val_accuracy: 0.6983
# Epoch 9/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8674 - accuracy: 0.6365 - val_loss: 0.8149 - val_accuracy: 0.6958
# Epoch 10/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.8357 - accuracy: 0.6414 - val_loss: 0.7841 - val_accuracy: 0.6862
# Epoch 11/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.8037 - accuracy: 0.6488 - val_loss: 0.7556 - val_accuracy: 0.6929
# Epoch 12/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7768 - accuracy: 0.6578 - val_loss: 0.7326 - val_accuracy: 0.6911
# Epoch 13/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7530 - accuracy: 0.6593 - val_loss: 0.7116 - val_accuracy: 0.6950
# Epoch 14/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7339 - accuracy: 0.6587 - val_loss: 0.6946 - val_accuracy: 0.6968
# Epoch 15/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7217 - accuracy: 0.6669 - val_loss: 0.6800 - val_accuracy: 0.6952
# Epoch 16/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7035 - accuracy: 0.6724 - val_loss: 0.6659 - val_accuracy: 0.6896
# Epoch 17/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6889 - accuracy: 0.6740 - val_loss: 0.6531 - val_accuracy: 0.6927
# Epoch 18/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.6714 - val_loss: 0.6438 - val_accuracy: 0.6981
# Epoch 19/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6719 - accuracy: 0.6720 - val_loss: 0.6351 - val_accuracy: 0.6940
# Epoch 20/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.6821 - val_loss: 0.6257 - val_accuracy: 0.6999
# Epoch 21/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6443 - accuracy: 0.6845 - val_loss: 0.6148 - val_accuracy: 0.7003
# Epoch 22/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6428 - accuracy: 0.6866 - val_loss: 0.6114 - val_accuracy: 0.7102
# Epoch 23/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6346 - accuracy: 0.6792 - val_loss: 0.5997 - val_accuracy: 0.6933
# Epoch 24/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.6767 - val_loss: 0.5935 - val_accuracy: 0.6935
# Epoch 25/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6163 - accuracy: 0.6859 - val_loss: 0.5872 - val_accuracy: 0.6942
# Epoch 26/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6127 - accuracy: 0.6886 - val_loss: 0.5821 - val_accuracy: 0.6968
# Epoch 27/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6064 - accuracy: 0.6841 - val_loss: 0.5759 - val_accuracy: 0.6966
# Epoch 28/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6000 - accuracy: 0.6851 - val_loss: 0.5712 - val_accuracy: 0.7015
# Epoch 29/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.6870 - val_loss: 0.5666 - val_accuracy: 0.6948
# Epoch 30/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5905 - accuracy: 0.6859 - val_loss: 0.5643 - val_accuracy: 0.6960
# Epoch 31/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5828 - accuracy: 0.6890 - val_loss: 0.5594 - val_accuracy: 0.6950
# Epoch 32/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.6876 - val_loss: 0.5550 - val_accuracy: 0.6970
# Epoch 33/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.6976 - val_loss: 0.5505 - val_accuracy: 0.6964
# Epoch 34/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5731 - accuracy: 0.6958 - val_loss: 0.5494 - val_accuracy: 0.7073
# Epoch 35/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5725 - accuracy: 0.6972 - val_loss: 0.5429 - val_accuracy: 0.7061
# Epoch 36/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5679 - accuracy: 0.6900 - val_loss: 0.5408 - val_accuracy: 0.7067
# Epoch 37/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5675 - accuracy: 0.6900 - val_loss: 0.5392 - val_accuracy: 0.6989
# Epoch 38/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5579 - accuracy: 0.6987 - val_loss: 0.5351 - val_accuracy: 0.7225
# Epoch 39/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5580 - accuracy: 0.7030 - val_loss: 0.5367 - val_accuracy: 0.6968
# Epoch 40/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5566 - accuracy: 0.6946 - val_loss: 0.5314 - val_accuracy: 0.7030
# Epoch 41/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5532 - accuracy: 0.6917 - val_loss: 0.5304 - val_accuracy: 0.6993
# Epoch 42/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5569 - accuracy: 0.6927 - val_loss: 0.5281 - val_accuracy: 0.6983
# Epoch 43/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5484 - accuracy: 0.6964 - val_loss: 0.5274 - val_accuracy: 0.6972
# Epoch 44/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.6995 - val_loss: 0.5313 - val_accuracy: 0.6968
# Epoch 45/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5463 - accuracy: 0.6890 - val_loss: 0.5261 - val_accuracy: 0.7093
# Epoch 46/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.6976 - val_loss: 0.5254 - val_accuracy: 0.7063
# Epoch 47/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.6948 - val_loss: 0.5270 - val_accuracy: 0.6983
# Epoch 48/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5431 - accuracy: 0.6880 - val_loss: 0.5211 - val_accuracy: 0.6974
# Epoch 49/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5428 - accuracy: 0.6989 - val_loss: 0.5202 - val_accuracy: 0.7061
# Epoch 50/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.6983 - val_loss: 0.5192 - val_accuracy: 0.7048
# Epoch 51/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.6950 - val_loss: 0.5186 - val_accuracy: 0.7042
# Epoch 52/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.6976 - val_loss: 0.5143 - val_accuracy: 0.7138
# Epoch 53/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5336 - accuracy: 0.6917 - val_loss: 0.5159 - val_accuracy: 0.7204
# Epoch 54/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5353 - accuracy: 0.6997 - val_loss: 0.5139 - val_accuracy: 0.7179
# Epoch 55/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5321 - accuracy: 0.6917 - val_loss: 0.5153 - val_accuracy: 0.7034
# Epoch 56/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5318 - accuracy: 0.7022 - val_loss: 0.5101 - val_accuracy: 0.7145
# Epoch 57/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.6980 - val_loss: 0.5088 - val_accuracy: 0.7089
# Epoch 58/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.6931 - val_loss: 0.5119 - val_accuracy: 0.7093
# Epoch 59/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5219 - accuracy: 0.6978 - val_loss: 0.5055 - val_accuracy: 0.7089
# Epoch 60/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.7046 - val_loss: 0.5089 - val_accuracy: 0.6989
# Epoch 61/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5240 - accuracy: 0.7007 - val_loss: 0.5082 - val_accuracy: 0.6970
# Epoch 62/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5229 - accuracy: 0.7091 - val_loss: 0.5046 - val_accuracy: 0.7118
# Epoch 63/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.6939 - val_loss: 0.5032 - val_accuracy: 0.7104
# Epoch 64/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7034 - val_loss: 0.5050 - val_accuracy: 0.7036
# Epoch 65/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5212 - accuracy: 0.6972 - val_loss: 0.5022 - val_accuracy: 0.7097
# Epoch 66/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5209 - accuracy: 0.6991 - val_loss: 0.5016 - val_accuracy: 0.7182
# Epoch 67/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5222 - accuracy: 0.6952 - val_loss: 0.5035 - val_accuracy: 0.7071
# Epoch 68/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5194 - accuracy: 0.7102 - val_loss: 0.5009 - val_accuracy: 0.7112
# Epoch 69/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5190 - accuracy: 0.7079 - val_loss: 0.5000 - val_accuracy: 0.7161
# Epoch 70/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5150 - accuracy: 0.7046 - val_loss: 0.5006 - val_accuracy: 0.7188
# Epoch 71/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.7030 - val_loss: 0.5072 - val_accuracy: 0.7019
# Epoch 72/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.6962 - val_loss: 0.5006 - val_accuracy: 0.7169
# Epoch 73/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5150 - accuracy: 0.7042 - val_loss: 0.4986 - val_accuracy: 0.7052
# Epoch 74/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5138 - accuracy: 0.7044 - val_loss: 0.5039 - val_accuracy: 0.6968
# Epoch 75/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.7038 - val_loss: 0.5001 - val_accuracy: 0.7112
# Epoch 76/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5123 - accuracy: 0.7040 - val_loss: 0.4965 - val_accuracy: 0.7073
# Epoch 77/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5131 - accuracy: 0.6970 - val_loss: 0.4995 - val_accuracy: 0.7169
# Epoch 78/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.7060 - val_loss: 0.4969 - val_accuracy: 0.7001
# Epoch 79/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5146 - accuracy: 0.7022 - val_loss: 0.4985 - val_accuracy: 0.7110
# Epoch 80/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5135 - accuracy: 0.7038 - val_loss: 0.4974 - val_accuracy: 0.7126
# Epoch 81/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5155 - accuracy: 0.7067 - val_loss: 0.4985 - val_accuracy: 0.7188
# Epoch 82/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5130 - accuracy: 0.7040 - val_loss: 0.4963 - val_accuracy: 0.7093
# Epoch 83/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5087 - accuracy: 0.7036 - val_loss: 0.4942 - val_accuracy: 0.7249
# Epoch 84/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.7042 - val_loss: 0.4940 - val_accuracy: 0.7184
# Epoch 85/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5068 - accuracy: 0.7034 - val_loss: 0.4925 - val_accuracy: 0.7221
# Epoch 86/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5055 - accuracy: 0.7048 - val_loss: 0.4939 - val_accuracy: 0.7251
# Epoch 87/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5095 - accuracy: 0.7048 - val_loss: 0.4908 - val_accuracy: 0.7196
# Epoch 88/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5075 - accuracy: 0.7091 - val_loss: 0.4933 - val_accuracy: 0.7229
# Epoch 89/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5084 - accuracy: 0.7099 - val_loss: 0.4901 - val_accuracy: 0.7177
# Epoch 90/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5055 - accuracy: 0.7020 - val_loss: 0.4915 - val_accuracy: 0.7128
# Epoch 91/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7100 - val_loss: 0.4915 - val_accuracy: 0.7214
# Epoch 92/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5049 - accuracy: 0.7151 - val_loss: 0.4937 - val_accuracy: 0.7173
# Epoch 93/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5051 - accuracy: 0.7134 - val_loss: 0.4888 - val_accuracy: 0.7274
# Epoch 94/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5024 - accuracy: 0.7155 - val_loss: 0.4920 - val_accuracy: 0.6997
# Epoch 95/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5038 - accuracy: 0.7118 - val_loss: 0.4906 - val_accuracy: 0.7118
# Epoch 96/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7089 - val_loss: 0.4863 - val_accuracy: 0.7192
# Epoch 97/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7083 - val_loss: 0.4881 - val_accuracy: 0.7151
# Epoch 98/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7063 - val_loss: 0.4881 - val_accuracy: 0.7260
# Epoch 99/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5012 - accuracy: 0.7136 - val_loss: 0.4865 - val_accuracy: 0.7171
# Epoch 100/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4994 - accuracy: 0.7128 - val_loss: 0.4860 - val_accuracy: 0.7300
# Epoch 101/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5012 - accuracy: 0.7122 - val_loss: 0.4856 - val_accuracy: 0.7145
# Epoch 102/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.7104 - val_loss: 0.4864 - val_accuracy: 0.7413
# Epoch 103/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7114 - val_loss: 0.4846 - val_accuracy: 0.7192
# Epoch 104/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4985 - accuracy: 0.7163 - val_loss: 0.4842 - val_accuracy: 0.7182
# Epoch 105/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4967 - accuracy: 0.7132 - val_loss: 0.4836 - val_accuracy: 0.7276
# Epoch 106/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.7153 - val_loss: 0.4886 - val_accuracy: 0.7177
# Epoch 107/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.7151 - val_loss: 0.4846 - val_accuracy: 0.7194
# Epoch 108/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4954 - accuracy: 0.7145 - val_loss: 0.4823 - val_accuracy: 0.7296
# Epoch 109/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7130 - val_loss: 0.4824 - val_accuracy: 0.7255
# Epoch 110/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4973 - accuracy: 0.7114 - val_loss: 0.4825 - val_accuracy: 0.7200
# Epoch 111/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4928 - accuracy: 0.7106 - val_loss: 0.4804 - val_accuracy: 0.7368
# Epoch 112/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.7161 - val_loss: 0.4879 - val_accuracy: 0.7440
# Epoch 113/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.7095 - val_loss: 0.4838 - val_accuracy: 0.7272
# Epoch 114/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7132 - val_loss: 0.4823 - val_accuracy: 0.7073
# Epoch 115/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4902 - accuracy: 0.7241 - val_loss: 0.4846 - val_accuracy: 0.7204
# Epoch 116/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4956 - accuracy: 0.7141 - val_loss: 0.4850 - val_accuracy: 0.7220
# Epoch 117/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4955 - accuracy: 0.7196 - val_loss: 0.4803 - val_accuracy: 0.7276
# Epoch 118/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4931 - accuracy: 0.7177 - val_loss: 0.4809 - val_accuracy: 0.7280
# Epoch 119/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4921 - accuracy: 0.7153 - val_loss: 0.4812 - val_accuracy: 0.7260
# Epoch 120/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4942 - accuracy: 0.7175 - val_loss: 0.4806 - val_accuracy: 0.7149
# Epoch 121/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4940 - accuracy: 0.7190 - val_loss: 0.4806 - val_accuracy: 0.7177
# Epoch 122/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4909 - accuracy: 0.7175 - val_loss: 0.4794 - val_accuracy: 0.7424
# Epoch 123/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4916 - accuracy: 0.7194 - val_loss: 0.4803 - val_accuracy: 0.7171
# Epoch 124/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4930 - accuracy: 0.7179 - val_loss: 0.4771 - val_accuracy: 0.7335
# Epoch 125/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4920 - accuracy: 0.7136 - val_loss: 0.4774 - val_accuracy: 0.7278
# Epoch 126/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4904 - accuracy: 0.7194 - val_loss: 0.4769 - val_accuracy: 0.7276
# Epoch 127/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.7083 - val_loss: 0.4757 - val_accuracy: 0.7436
# Epoch 128/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4892 - accuracy: 0.7202 - val_loss: 0.4751 - val_accuracy: 0.7241
# Epoch 129/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.7153 - val_loss: 0.4749 - val_accuracy: 0.7385
# Epoch 130/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4894 - accuracy: 0.7177 - val_loss: 0.4757 - val_accuracy: 0.7276
# Epoch 131/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4864 - accuracy: 0.7182 - val_loss: 0.4765 - val_accuracy: 0.7198
# Epoch 132/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4939 - accuracy: 0.7118 - val_loss: 0.4754 - val_accuracy: 0.7303
# Epoch 133/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4904 - accuracy: 0.7235 - val_loss: 0.4763 - val_accuracy: 0.7374
# Epoch 134/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4901 - accuracy: 0.7124 - val_loss: 0.4740 - val_accuracy: 0.7243
# Epoch 135/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4869 - accuracy: 0.7259 - val_loss: 0.4730 - val_accuracy: 0.7417
# Epoch 136/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4907 - accuracy: 0.7151 - val_loss: 0.4748 - val_accuracy: 0.7180
# Epoch 137/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4877 - accuracy: 0.7264 - val_loss: 0.4717 - val_accuracy: 0.7350
# Epoch 138/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4869 - accuracy: 0.7202 - val_loss: 0.4726 - val_accuracy: 0.7436
# Epoch 139/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4858 - accuracy: 0.7186 - val_loss: 0.4720 - val_accuracy: 0.7333
# Epoch 140/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4905 - accuracy: 0.7259 - val_loss: 0.4737 - val_accuracy: 0.7282
# Epoch 141/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4857 - accuracy: 0.7239 - val_loss: 0.4727 - val_accuracy: 0.7362
# Epoch 142/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4874 - accuracy: 0.7153 - val_loss: 0.4719 - val_accuracy: 0.7362
# Epoch 143/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.7196 - val_loss: 0.4713 - val_accuracy: 0.7354
# Epoch 144/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4867 - accuracy: 0.7212 - val_loss: 0.4758 - val_accuracy: 0.7204
# Epoch 145/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4884 - accuracy: 0.7288 - val_loss: 0.4720 - val_accuracy: 0.7301
# Epoch 146/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4858 - accuracy: 0.7149 - val_loss: 0.4692 - val_accuracy: 0.7405
# Epoch 147/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4851 - accuracy: 0.7229 - val_loss: 0.4707 - val_accuracy: 0.7344
# Epoch 148/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4879 - accuracy: 0.7182 - val_loss: 0.4755 - val_accuracy: 0.7284
# Epoch 149/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.7255 - val_loss: 0.4682 - val_accuracy: 0.7364
# Epoch 150/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4834 - accuracy: 0.7192 - val_loss: 0.4681 - val_accuracy: 0.7303
# Epoch 151/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4810 - accuracy: 0.7143 - val_loss: 0.4686 - val_accuracy: 0.7243
# Epoch 152/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4822 - accuracy: 0.7352 - val_loss: 0.4705 - val_accuracy: 0.7165
# Epoch 153/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4806 - accuracy: 0.7147 - val_loss: 0.4692 - val_accuracy: 0.7368
# Epoch 154/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4841 - accuracy: 0.7220 - val_loss: 0.4687 - val_accuracy: 0.7288
# Epoch 155/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4818 - accuracy: 0.7190 - val_loss: 0.4742 - val_accuracy: 0.7194
# Epoch 156/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4840 - accuracy: 0.7237 - val_loss: 0.4676 - val_accuracy: 0.7340
# Epoch 157/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4831 - accuracy: 0.7257 - val_loss: 0.4690 - val_accuracy: 0.7200
# Epoch 158/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.7280 - val_loss: 0.4695 - val_accuracy: 0.7522
# Epoch 159/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4802 - accuracy: 0.7235 - val_loss: 0.4659 - val_accuracy: 0.7436
# Epoch 160/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4774 - accuracy: 0.7317 - val_loss: 0.4682 - val_accuracy: 0.7489
# Epoch 161/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.7235 - val_loss: 0.4672 - val_accuracy: 0.7329
# Epoch 162/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4793 - accuracy: 0.7264 - val_loss: 0.4723 - val_accuracy: 0.7381
# Epoch 163/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.7223 - val_loss: 0.4763 - val_accuracy: 0.7214
# Epoch 164/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4848 - accuracy: 0.7260 - val_loss: 0.4663 - val_accuracy: 0.7415
# Epoch 165/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4810 - accuracy: 0.7298 - val_loss: 0.4649 - val_accuracy: 0.7582
# Epoch 166/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4804 - accuracy: 0.7255 - val_loss: 0.4645 - val_accuracy: 0.7358
# Epoch 167/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4797 - accuracy: 0.7257 - val_loss: 0.4638 - val_accuracy: 0.7210
# Epoch 168/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4800 - accuracy: 0.7227 - val_loss: 0.4689 - val_accuracy: 0.7294
# Epoch 169/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4795 - accuracy: 0.7212 - val_loss: 0.4646 - val_accuracy: 0.7360
# Epoch 170/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4804 - accuracy: 0.7264 - val_loss: 0.4626 - val_accuracy: 0.7426
# Epoch 171/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.7251 - val_loss: 0.4626 - val_accuracy: 0.7428
# Epoch 172/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4802 - accuracy: 0.7218 - val_loss: 0.4654 - val_accuracy: 0.7323
# Epoch 173/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.7262 - val_loss: 0.4640 - val_accuracy: 0.7227
# Epoch 174/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4815 - accuracy: 0.7253 - val_loss: 0.4640 - val_accuracy: 0.7286
# Epoch 175/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4805 - accuracy: 0.7270 - val_loss: 0.4662 - val_accuracy: 0.7422
# Epoch 176/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4781 - accuracy: 0.7272 - val_loss: 0.4661 - val_accuracy: 0.7594
# Epoch 177/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4805 - accuracy: 0.7329 - val_loss: 0.4617 - val_accuracy: 0.7625
# Epoch 178/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4774 - accuracy: 0.7342 - val_loss: 0.4622 - val_accuracy: 0.7563
# Epoch 179/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4730 - accuracy: 0.7411 - val_loss: 0.4617 - val_accuracy: 0.7528
# Epoch 180/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4721 - accuracy: 0.7270 - val_loss: 0.4615 - val_accuracy: 0.7659
# Epoch 181/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4790 - accuracy: 0.7274 - val_loss: 0.4671 - val_accuracy: 0.7202
# Epoch 182/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.7327 - val_loss: 0.4612 - val_accuracy: 0.7436
# Epoch 183/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4744 - accuracy: 0.7300 - val_loss: 0.4588 - val_accuracy: 0.7497
# Epoch 184/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.7225 - val_loss: 0.4592 - val_accuracy: 0.7397
# Epoch 185/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4719 - accuracy: 0.7403 - val_loss: 0.4619 - val_accuracy: 0.7333
# Epoch 186/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4700 - accuracy: 0.7337 - val_loss: 0.4622 - val_accuracy: 0.7247
# Epoch 187/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4729 - accuracy: 0.7307 - val_loss: 0.4581 - val_accuracy: 0.7417
# Epoch 188/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4774 - accuracy: 0.7339 - val_loss: 0.4679 - val_accuracy: 0.7204
# Epoch 189/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.7311 - val_loss: 0.4595 - val_accuracy: 0.7368
# Epoch 190/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4725 - accuracy: 0.7348 - val_loss: 0.4583 - val_accuracy: 0.7337
# Epoch 191/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.7366 - val_loss: 0.4678 - val_accuracy: 0.7612
# Epoch 192/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7315 - val_loss: 0.4614 - val_accuracy: 0.7703
# Epoch 193/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4777 - accuracy: 0.7284 - val_loss: 0.4581 - val_accuracy: 0.7456
# Epoch 194/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7301 - val_loss: 0.4566 - val_accuracy: 0.7413
# Epoch 195/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4717 - accuracy: 0.7290 - val_loss: 0.4597 - val_accuracy: 0.7360
# Epoch 196/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4726 - accuracy: 0.7286 - val_loss: 0.4626 - val_accuracy: 0.7692
# Epoch 197/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4746 - accuracy: 0.7387 - val_loss: 0.4577 - val_accuracy: 0.7579
# Epoch 198/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4701 - accuracy: 0.7305 - val_loss: 0.4570 - val_accuracy: 0.7374
# Epoch 199/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.7374 - val_loss: 0.4612 - val_accuracy: 0.7196
# Epoch 200/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7364 - val_loss: 0.4571 - val_accuracy: 0.7458
# Epoch 201/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.7284 - val_loss: 0.4716 - val_accuracy: 0.7218
# Epoch 202/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.7325 - val_loss: 0.4561 - val_accuracy: 0.7487
# Epoch 203/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4715 - accuracy: 0.7342 - val_loss: 0.4566 - val_accuracy: 0.7434
# Epoch 204/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4740 - accuracy: 0.7294 - val_loss: 0.4559 - val_accuracy: 0.7698
# Epoch 205/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4791 - accuracy: 0.7245 - val_loss: 0.4566 - val_accuracy: 0.7344
# Epoch 206/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4723 - accuracy: 0.7403 - val_loss: 0.4606 - val_accuracy: 0.7405
# Epoch 207/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4702 - accuracy: 0.7393 - val_loss: 0.4558 - val_accuracy: 0.7647
# Epoch 208/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4769 - accuracy: 0.7364 - val_loss: 0.4580 - val_accuracy: 0.7432
# Epoch 209/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.7356 - val_loss: 0.4566 - val_accuracy: 0.7362
# Epoch 210/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.7276 - val_loss: 0.4597 - val_accuracy: 0.7319
# Epoch 211/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.7311 - val_loss: 0.4569 - val_accuracy: 0.7346
# Epoch 212/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4723 - accuracy: 0.7307 - val_loss: 0.4550 - val_accuracy: 0.7604
# Epoch 213/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4721 - accuracy: 0.7329 - val_loss: 0.4577 - val_accuracy: 0.7339
# Epoch 214/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7282 - val_loss: 0.4590 - val_accuracy: 0.7354
# Epoch 215/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4721 - accuracy: 0.7239 - val_loss: 0.4523 - val_accuracy: 0.7500
# Epoch 216/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4675 - accuracy: 0.7340 - val_loss: 0.4539 - val_accuracy: 0.7473
# Epoch 217/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.7399 - val_loss: 0.4566 - val_accuracy: 0.7559
# Epoch 218/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4673 - accuracy: 0.7348 - val_loss: 0.4519 - val_accuracy: 0.7635
# Epoch 219/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4648 - accuracy: 0.7448 - val_loss: 0.4548 - val_accuracy: 0.7354
# Epoch 220/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7434 - val_loss: 0.4531 - val_accuracy: 0.7471
# Epoch 221/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4683 - accuracy: 0.7409 - val_loss: 0.4518 - val_accuracy: 0.7740
# Epoch 222/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4672 - accuracy: 0.7329 - val_loss: 0.4526 - val_accuracy: 0.7411
# Epoch 223/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4663 - accuracy: 0.7424 - val_loss: 0.4519 - val_accuracy: 0.7446
# Epoch 224/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4690 - accuracy: 0.7403 - val_loss: 0.4570 - val_accuracy: 0.7727
# Epoch 225/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4706 - accuracy: 0.7368 - val_loss: 0.4560 - val_accuracy: 0.7467
# Epoch 226/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.7354 - val_loss: 0.4511 - val_accuracy: 0.7461
# Epoch 227/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7348 - val_loss: 0.4527 - val_accuracy: 0.7403
# Epoch 228/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4669 - accuracy: 0.7368 - val_loss: 0.4497 - val_accuracy: 0.7395
# Epoch 229/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4681 - accuracy: 0.7358 - val_loss: 0.4505 - val_accuracy: 0.7473
# Epoch 230/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4691 - accuracy: 0.7340 - val_loss: 0.4507 - val_accuracy: 0.7456
# Epoch 231/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.7337 - val_loss: 0.4515 - val_accuracy: 0.7469
# Epoch 232/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.7440 - val_loss: 0.4491 - val_accuracy: 0.7362
# Epoch 233/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.7342 - val_loss: 0.4510 - val_accuracy: 0.7500
# Epoch 234/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.4677 - accuracy: 0.7387 - val_loss: 0.4510 - val_accuracy: 0.7436
# Epoch 235/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.7362 - val_loss: 0.4503 - val_accuracy: 0.7463
# Epoch 236/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4654 - accuracy: 0.7335 - val_loss: 0.4536 - val_accuracy: 0.7522
# Epoch 237/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.7286 - val_loss: 0.4482 - val_accuracy: 0.7426
# Epoch 238/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4701 - accuracy: 0.7411 - val_loss: 0.4514 - val_accuracy: 0.7399
# Epoch 239/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.7296 - val_loss: 0.4522 - val_accuracy: 0.7469
# Epoch 240/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7387 - val_loss: 0.4530 - val_accuracy: 0.7348
# Epoch 241/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4693 - accuracy: 0.7309 - val_loss: 0.4571 - val_accuracy: 0.7346
# Epoch 242/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.7436 - val_loss: 0.4509 - val_accuracy: 0.7417
# Epoch 243/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4640 - accuracy: 0.7409 - val_loss: 0.4477 - val_accuracy: 0.7432
# Epoch 244/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7411 - val_loss: 0.4487 - val_accuracy: 0.7485
# Epoch 245/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.7417 - val_loss: 0.4525 - val_accuracy: 0.7491
# Epoch 246/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4600 - accuracy: 0.7424 - val_loss: 0.4510 - val_accuracy: 0.7577
# Epoch 247/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4643 - accuracy: 0.7344 - val_loss: 0.4493 - val_accuracy: 0.7580
# Epoch 248/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4665 - accuracy: 0.7397 - val_loss: 0.4504 - val_accuracy: 0.7625
# Epoch 249/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4648 - accuracy: 0.7380 - val_loss: 0.4465 - val_accuracy: 0.7504
# Epoch 250/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4658 - accuracy: 0.7419 - val_loss: 0.4466 - val_accuracy: 0.7739
# Epoch 251/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4606 - accuracy: 0.7424 - val_loss: 0.4454 - val_accuracy: 0.7450
# Epoch 252/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4611 - accuracy: 0.7385 - val_loss: 0.4460 - val_accuracy: 0.7391
# Epoch 253/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4645 - accuracy: 0.7395 - val_loss: 0.4478 - val_accuracy: 0.7499
# Epoch 254/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.4623 - accuracy: 0.7430 - val_loss: 0.4498 - val_accuracy: 0.7481
# Epoch 255/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4631 - accuracy: 0.7411 - val_loss: 0.4456 - val_accuracy: 0.7674
# Epoch 256/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7385 - val_loss: 0.4485 - val_accuracy: 0.7508
# Epoch 257/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4641 - accuracy: 0.7428 - val_loss: 0.4466 - val_accuracy: 0.7657
# Epoch 258/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.7389 - val_loss: 0.4473 - val_accuracy: 0.7588
# Epoch 259/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4662 - accuracy: 0.7446 - val_loss: 0.4435 - val_accuracy: 0.7680
# Epoch 260/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4608 - accuracy: 0.7465 - val_loss: 0.4465 - val_accuracy: 0.7358
# Epoch 261/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.7463 - val_loss: 0.4472 - val_accuracy: 0.7610
# Epoch 262/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4640 - accuracy: 0.7358 - val_loss: 0.4473 - val_accuracy: 0.7485
# Epoch 263/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.7528 - val_loss: 0.4449 - val_accuracy: 0.7381
# Epoch 264/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4616 - accuracy: 0.7399 - val_loss: 0.4432 - val_accuracy: 0.7497
# Epoch 265/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.7526 - val_loss: 0.4437 - val_accuracy: 0.7397
# Epoch 266/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.7311 - val_loss: 0.4454 - val_accuracy: 0.7600
# Epoch 267/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4603 - accuracy: 0.7446 - val_loss: 0.4459 - val_accuracy: 0.7504
# Epoch 268/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4557 - accuracy: 0.7500 - val_loss: 0.4462 - val_accuracy: 0.7512
# Epoch 269/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4592 - accuracy: 0.7452 - val_loss: 0.4425 - val_accuracy: 0.7645
# Epoch 270/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4577 - accuracy: 0.7454 - val_loss: 0.4471 - val_accuracy: 0.7610
# Epoch 271/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4575 - accuracy: 0.7409 - val_loss: 0.4439 - val_accuracy: 0.7493
# Epoch 272/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4565 - accuracy: 0.7442 - val_loss: 0.4417 - val_accuracy: 0.7735
# Epoch 273/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.7481 - val_loss: 0.4439 - val_accuracy: 0.7485
# Epoch 274/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.7467 - val_loss: 0.4453 - val_accuracy: 0.7567
# Epoch 275/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.7370 - val_loss: 0.4455 - val_accuracy: 0.7514
# Epoch 276/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4630 - accuracy: 0.7337 - val_loss: 0.4484 - val_accuracy: 0.7565
# Epoch 277/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.7428 - val_loss: 0.4445 - val_accuracy: 0.7701
# Epoch 278/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4651 - accuracy: 0.7446 - val_loss: 0.4529 - val_accuracy: 0.7292
# Epoch 279/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4622 - accuracy: 0.7422 - val_loss: 0.4465 - val_accuracy: 0.7383
# Epoch 280/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4612 - accuracy: 0.7391 - val_loss: 0.4453 - val_accuracy: 0.7374
# Epoch 281/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7514 - val_loss: 0.4446 - val_accuracy: 0.7672
# Epoch 282/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.7323 - val_loss: 0.4417 - val_accuracy: 0.7791
# Epoch 283/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4650 - accuracy: 0.7415 - val_loss: 0.4434 - val_accuracy: 0.7553
# Epoch 284/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7409 - val_loss: 0.4413 - val_accuracy: 0.7729
# Epoch 285/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7415 - val_loss: 0.4405 - val_accuracy: 0.7555
# Epoch 286/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.7426 - val_loss: 0.4411 - val_accuracy: 0.7444
# Epoch 287/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.7417 - val_loss: 0.4424 - val_accuracy: 0.7610
# Epoch 288/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7333 - val_loss: 0.4428 - val_accuracy: 0.7637
# Epoch 289/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.7399 - val_loss: 0.4450 - val_accuracy: 0.7460
# Epoch 290/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.7460 - val_loss: 0.4381 - val_accuracy: 0.7686
# Epoch 291/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4539 - accuracy: 0.7456 - val_loss: 0.4389 - val_accuracy: 0.7696
# Epoch 292/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7481 - val_loss: 0.4442 - val_accuracy: 0.7514
# Epoch 293/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4604 - accuracy: 0.7395 - val_loss: 0.4445 - val_accuracy: 0.7510
# Epoch 294/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4622 - accuracy: 0.7420 - val_loss: 0.4487 - val_accuracy: 0.7526
# Epoch 295/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.7497 - val_loss: 0.4520 - val_accuracy: 0.7565
# Epoch 296/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.7417 - val_loss: 0.4447 - val_accuracy: 0.7655
# Epoch 297/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4580 - accuracy: 0.7477 - val_loss: 0.4417 - val_accuracy: 0.7526
# Epoch 298/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.7426 - val_loss: 0.4463 - val_accuracy: 0.7381
# Epoch 299/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4602 - accuracy: 0.7399 - val_loss: 0.4476 - val_accuracy: 0.7481
# Epoch 300/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.7458 - val_loss: 0.4456 - val_accuracy: 0.7510

# %% [markdown]
# Let's plot the Loss vs Epoch chart.

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %% [markdown]
# Let's evaluate the trained model.

# %%
print("Loss, Accuracy: ", model.evaluate(X_test, y_cat_test))
# Out:
# 161/161 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.7510
# Loss, Accuracy:  [0.44556963443756104, 0.7510243654251099]

# %%
print("F1-score: ", f1_score(y_test, np.argmax(model.predict(X_test), axis=1), average='weighted'))
# Out:
# 161/161 [==============================] - 0s 1ms/step
# F1-score:  0.7440572544530973

# %% [markdown]
# With a simple NN model a F1-score of approximately 70% was achieved.
#
# There is always room for model fine-tuning, optimizations and futher model improvements.
